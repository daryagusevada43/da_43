# %% [markdown]
# # Оглавление
# * [Описание проекта](#chapter1)
# * [Предобработка данных](#chapter2)
#    * [Работа с дубликатами](#chapter3)
#    * [Работа с пропусками](#chapter4)
# * [Исследовательский анализ данных](#chapter5)
#    * [Выявление грейда требуемых специалистов](#chapter6)
#    * [Определение доли грейдов](#chapter7)

# %% [markdown]
# ## Описание проекта <a id="chapter1"></a>

# %% [markdown]
# Вам предстоит поработать с задачей, с которой зачастую сталкиваются аналитики рекрутингового агентства.
# В рамках проекта вы поработаете с реальными данными портала HH.ru
#
# Цель: Выявить различия в предлагаемых вакансиях для Аналитиков данных и Системных аналитиков.
#
# 1.	Предобработка данных
# 2.	Исследовательский анализ данных
# 3.	Выявление грейда требуемых специалистов по названию вакансии или по колонке с требуемым опытом
# 4.	Определение доли грейдов Junior, Junior+, Middle, Senior среди вакансий Аналитик данных и Системный Аналитик
# 5.	Определение типичного места работы для Аналитика Данных и Системного Аналитика по следующим параметрам: ТОП-работодателей, зарплата, тип занятости, график работы,
# Ответ нужен для грейдов Junior, Junior+, Middle, Senior
# 6.	Определите, какие навыки спрашивают чаще hard или soft
# 7.	Определите наиболее желаемых кандидатов на вакансии Аналитика Данных и Системного Аналитика по следующим параметрам: самые важные hard-skills, cамые важные soft-skills. Ответ дайте отдельно для Junior, Junior+, Middle, Senior
# 8.	Формулировка выводов и рекомендаций

# %% [markdown]
# Описание полей в данных
# * id - Уникальный идентификатор вакансии.
# * name - Название вакансии.
# * published_at - Дата публикации.
# * alternate_url - Ссылка на вакансию.
# * type - Статус вакансии на момент получения данных от api и передачи
# их в базу.
# * employer - Работодатель.
# * department - Работодатель, отдел.
# * area - Регион места работы.
# * experience - Требуемый опыт работы.
# * key_skills - Ключевые навыки, в том числе найденные при анализе
# полного текста вакансии. Поле генерируется после получения
# информации от api.
# * schedule - График работы.
# * employment - Тип занятости.
# * description - Описание вакансии.
# * description_lemmatized - Лемматизированное описание вакансии.
# * salary_from - Нижняя граница предлагаемой заработной платы.
# * salary_to - Верхняя граница предлагаемой заработной платы.
# * salary_bin - Категория зарплаты.
# * key_skills_from_key_skills_field - Ключевые навыки из поля вакансии
# key_skills.
# * hard_skills_from_description - “Твердые” навыки, найденные при
# обработке полей с навыками. Поле генерируется после получения
# информации от api. soft_skills_from_description - “Мягкие” навыки,
# найденные при обработке полей с навыками. Поле генерируется после
# получения информации от api.

# %% [markdown]
# ## Предобработка данных <a id="chapter2"></a>

# %%
#импортируем библиотеки
import pandas as pd
import requests
import re
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from collections import Counter

# %%
#читаем файлы
da = pd.read_excel(r"C:\Users\Guseva\Downloads\vacancies_da.xlsx")
sa = pd.read_excel(r"C:\Users\Guseva\Downloads\vacancies_sa.xlsx")

# %%
# устанавливаем максимальное количество отображаемых столбцов
pd.set_option('display.max_columns', None)

# отключаем экспоненциальную форму чисел
pd.set_option('display.float_format', '{:.2f}'.format)

# %%
# функция которая выводит короткую справку о датасете
def brief(df):
    
        print(f"\nИнформация по датасету\n")
        
        print("Первые пять строк датафрейма:")
        display(df.head())
        print()
        
        print("Описательная статистика:")
        display(df.describe())
        print()
        
        print("Общая информация о датафрейме:")
        df.info()
        print()
        
        print(f"Количество явных дубликатов в датафрейме: {df.duplicated().sum()}")
        print()
        
        print("Процент пропущенных значений в столбцах:")
        for column in df.columns:
            missing_percentage = df[column].isna().mean() * 100
            if missing_percentage > 0:
                print(f"{column}: {missing_percentage:.2f}%")

# %%
brief(da)
# Out:
# Информация по датасету
#
# Первые пять строк датафрейма:
#           id                                    name        published_at  \
# 0  100039284  Junior аналитик данных (исследователь) 2024-05-24 09:37:04
# 1  100039480                         Аналитик данных 2024-05-24 09:39:00
# 2  100042705         Аналитик данных (исследователь) 2024-05-24 10:01:25
# 3  100046788                 Ведущий аналитик данных 2024-05-24 10:28:18
# 4  100056244                         Аналитик данных 2024-05-24 11:27:40
#
#                      alternate_url      type           employer  \
# 0  https://hh.ru/vacancy/100039284  Открытая  DNS Головной офис
# 1  https://hh.ru/vacancy/100039480  Открытая              Комус
# 2  https://hh.ru/vacancy/100042705  Открытая  DNS Головной офис
# 3  https://hh.ru/vacancy/100046788  Открытая           Х5 Group
# 4  https://hh.ru/vacancy/100056244  Открытая             ЛУКОЙЛ
#
#                    department         area             experience  \
# 0                         NaN  Владивосток  Junior (no experince)
# 1                         NaN       Москва  Junior (no experince)
# 2                         NaN  Владивосток    Junior+ (1-3 years)
# 3  X5 GROUP, Центральный офис       Москва    Junior+ (1-3 years)
# 4                         NaN       Москва     Middle (3-6 years)
#
#                                           key_skills     schedule  \
# 0              ['Power BI', 'СУБД', 'Python', 'SQL']  Полный день
# 1   ['MS SQL', 'Работа с базами данных', 'MS Excel']  Полный день
# 2  ['SQL', 'Power BI', 'СУБД', 'Python', 'Clickho...  Полный день
# 3  ['Анализ данных', 'Коммуникация', 'SQL', 'MS O...  Полный день
# 4                                   ['Документация']  Полный день
#
#          employment                                        description  \
# 0  Полная занятость  наше направление занимается повышением эффекти...
# 1  Полная занятость  сегодня комус один из крупнейших поставщиков о...
# 2  Полная занятость  наше направление занимается повышением эффекти...
# 3  Полная занятость  задачи:  разработка бизнес-моделей для группов...
# 4  Полная занятость  обязанности:  участие в проектировании, разраб...
#
#                               description_lemmatized  salary_from  salary_to  \
# 0  наш направление заниматься повышение эффективн...     60000.00        NaN
# 1  сегодня комус крупный поставщик офисный товар ...          NaN        NaN
# 2  наш направление заниматься повышение эффективн...     90000.00        NaN
# 3  задача разработка бизнес модель групповой прог...          NaN        NaN
# 4  обязанность участие проектирование разработка ...          NaN        NaN
#
#       salary_bin                   key_skills_from_key_skills_field  \
# 0  ЗП не указана                        SQL, Power BI, Python, СУБД
# 1  ЗП не указана           Работа с базами данных, MS SQL, MS Excel
# 2  ЗП не указана      SQL, Power BI, Python, СУБД, BPMN, Clickhouse
# 3  ЗП не указана  MS Office, SQL, Python, Hadoop, Нive, Аналитич...
# 4  ЗП не указана                                                NaN
#
#   hard_skills_from_description soft_skills_from_description
# 0                          NaN                          NaN
# 1                          NaN                          NaN
# 2                          NaN                          NaN
# 3       Pandas, Юнит-экономика                 Коммуникация
# 4                          NaN                 Документация
# Описательная статистика:
#                 id  salary_from  salary_to
# count      1801.00       348.00     228.00
# mean   97226464.30    109525.09  153846.71
# std     2894521.85     63011.34   97255.74
# min    77992314.00        50.00   25000.00
# 25%    95448125.00     70000.00   85000.00
# 50%    97356356.00     90000.00  120000.00
# 75%    99425261.00    137750.00  200000.00
# max   101746482.00    398000.00  497500.00
# Общая информация о датафрейме:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1801 entries, 0 to 1800
# Data columns (total 20 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   id                                1801 non-null   int64
#  1   name                              1801 non-null   object
#  2   published_at                      1801 non-null   datetime64[ns]
#  3   alternate_url                     1801 non-null   object
#  4   type                              1801 non-null   object
#  5   employer                          1801 non-null   object
#  6   department                        521 non-null    object
#  7   area                              1801 non-null   object
#  8   experience                        1801 non-null   object
#  9   key_skills                        1801 non-null   object
#  10  schedule                          1801 non-null   object
#  11  employment                        1801 non-null   object
#  12  description                       1801 non-null   object
#  13  description_lemmatized            1801 non-null   object
#  14  salary_from                       348 non-null    float64
#  15  salary_to                         228 non-null    float64
#  16  salary_bin                        1801 non-null   object
#  17  key_skills_from_key_skills_field  1093 non-null   object
#  18  hard_skills_from_description      418 non-null    object
#  19  soft_skills_from_description      588 non-null    object
# dtypes: datetime64[ns](1), float64(2), int64(1), object(16)
# memory usage: 281.5+ KB
#
# Количество явных дубликатов в датафрейме: 0
#
# Процент пропущенных значений в столбцах:
# department: 71.07%
# salary_from: 80.68%
# salary_to: 87.34%
# key_skills_from_key_skills_field: 39.31%
# hard_skills_from_description: 76.79%
# soft_skills_from_description: 67.35%

# %%
brief(sa)
# Out:
# Информация по датасету
#
# Первые пять строк датафрейма:
#           id                            name        published_at  \
# 0  100046399              Системный аналитик 2024-07-08 10:22:57
# 1  100050107       Бизнес/Системный Аналитик 2024-07-06 17:19:32
# 2  100059559           Системный IT аналитик 2024-07-08 11:48:17
# 3  100063260  Системный Аналитик ERP-решений 2024-07-09 10:51:54
# 4  100064793              Системный аналитик 2024-07-08 16:39:40
#
#                      alternate_url      type           employer department  \
# 0  https://hh.ru/vacancy/100046399  Открытая              Юрент        NaN
# 1  https://hh.ru/vacancy/100050107  Открытая               Surf        NaN
# 2  https://hh.ru/vacancy/100059559  Открытая           AMarkets        NaN
# 3  https://hh.ru/vacancy/100063260  Открытая              Астор        NaN
# 4  https://hh.ru/vacancy/100064793  Открытая  Зетта Страхование        NaN
#
#               area           experience  \
# 0           Москва   Middle (3-6 years)
# 1  Санкт-Петербург  Junior+ (1-3 years)
# 2           Москва  Junior+ (1-3 years)
# 3           Москва    Senior (6+ years)
# 4           Москва  Junior+ (1-3 years)
#
#                                           key_skills          schedule  \
# 0  ['1С', 'Аналитический склад ума', 'confluence'...       Полный день
# 1  ['Разработка технических заданий', 'Бизнес-ана...  Удаленная работа
# 2                                   ['Документация']       Полный день
# 3  ['ERP', 'Atlassian Jira', '1С: Управление Прои...  Удаленная работа
# 4  ['JSON', 'SQL', 'XML', 'SOAP', 'HTML', 'JS', '...       Полный день
#
#          employment                                        description  \
# 0  Полная занятость  юрент — это новый уровень городской мобильност...
# 1  Полная занятость  в surf уже 13 лет мы разрабатываем много разны...
# 2  Полная занятость  мы - международная fintech компания amarkets, ...
# 3  Полная занятость  компания «астор» с 2000 года занимается разраб...
# 4  Полная занятость  обязанности:   анализ задач развития и сопрово...
#
#                               description_lemmatized  salary_from  salary_to  \
# 0  юрент новый уровень городской мобильность круп...          NaN        NaN
# 1  surf 13 год разрабатывать разный продукт начин...          NaN        NaN
# 2  международный fintech компания amarkets 2 7 го...    233750.00        NaN
# 3  компания астор 2 год заниматься разработка вне...          NaN        NaN
# 4  обязанность анализ задача развитие сопровожден...          NaN        NaN
#
#       salary_bin                   key_skills_from_key_skills_field  \
# 0  ЗП не указана                   SQL, Аналитический склад ума, 1С
# 1  ЗП не указана  BPMN, UML, Английский язык, Системный анализ, ...
# 2  ЗП не указана                                                NaN
# 3  ЗП не указана  ERP, 1С: Управление Торговлей, Atlassian Jira,...
# 4  ЗП не указана      SQL, C#, Java, JS, SOAP, JSON, XML, HTML, CSS
#
#   hard_skills_from_description soft_skills_from_description
# 0                   confluence                          NaN
# 1                          NaN                 Документация
# 2                          NaN                 Документация
# 3                   confluence                 Коммуникация
# 4                          NaN                          NaN
# Описательная статистика:
#                 id  salary_from  salary_to
# count      1915.00       356.00     279.00
# mean  100107444.71    154117.59  223633.58
# std     5214258.45     74335.13  103654.64
# min    52410168.00       280.00   20000.00
# 25%    98814421.00     85000.00  145000.00
# 50%   102288353.00    150000.00  220000.00
# 75%   103131490.00    200000.00  300000.00
# max   103584669.00    350000.00  580000.00
# Общая информация о датафрейме:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1915 entries, 0 to 1914
# Data columns (total 20 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   id                                1915 non-null   int64
#  1   name                              1915 non-null   object
#  2   published_at                      1915 non-null   datetime64[ns]
#  3   alternate_url                     1915 non-null   object
#  4   type                              1915 non-null   object
#  5   employer                          1915 non-null   object
#  6   department                        361 non-null    object
#  7   area                              1915 non-null   object
#  8   experience                        1915 non-null   object
#  9   key_skills                        1915 non-null   object
#  10  schedule                          1915 non-null   object
#  11  employment                        1915 non-null   object
#  12  description                       1915 non-null   object
#  13  description_lemmatized            1915 non-null   object
#  14  salary_from                       356 non-null    float64
#  15  salary_to                         279 non-null    float64
#  16  salary_bin                        1915 non-null   object
#  17  key_skills_from_key_skills_field  1274 non-null   object
#  18  hard_skills_from_description      570 non-null    object
#  19  soft_skills_from_description      1427 non-null   object
# dtypes: datetime64[ns](1), float64(2), int64(1), object(16)
# memory usage: 299.3+ KB
#
# Количество явных дубликатов в датафрейме: 0
#
# Процент пропущенных значений в столбцах:
# department: 81.15%
# salary_from: 81.41%
# salary_to: 85.43%
# key_skills_from_key_skills_field: 33.47%
# hard_skills_from_description: 70.23%
# soft_skills_from_description: 25.48%

# %% [markdown]
# На первый взгляд в представленных датасетах:
# 1. явных дубликатов не обнаружено,
# 2. типы данных соответствуют описанию,
# 3. названия столбцов соответствуют snake case и в обоих таблицах идентичны
# 4. больше всего пропусков в столбцах с зарплатными данными
# 5. меньше всего пропусков в таблице с вакансиями дата аналитиков в столбце с ключевыми навыками из описания, а в датасете с вакансиями системных аналитиков меньше всего пропусков в софт скиллах.
# 6. в статистической справке привлекают внимание минимальные значения зарплат в 50 рублей для дата аналитика и 280 рублей для системного аналитика.

# %%
#копируем таблицы, чтобы сохранить исходные данные
data_analysts = da.copy()
sistem_analysts = sa.copy()

# %% [markdown]
# Исследуем минимальные зарплаты аналитиков

# %%
data_analysts.query('salary_from < 20000')
# Out:
#             id                                               name  \
# 1110  96943446  Аналитик данных в отдел развития на маркетплейсах
#
#             published_at                   alternate_url      type  \
# 1110 2024-05-11 21:45:07  https://hh.ru/vacancy/96943446  Открытая
#
#                       employer department    area             experience  \
# 1110  Репетуев Иван Дмитриевич        NaN  Москва  Junior (no experince)
#
#                                              key_skills          schedule  \
# 1110  ['Аналитическое мышление', 'Аналитика продаж',...  Удаленная работа
#
#             employment                                        description  \
# 1110  Полная занятость  ищу в команду аналитика до глубины мозга косте...
#
#                                  description_lemmatized  salary_from  \
# 1110  искать команда аналитик глубина мозг кость име...        50.00
#
#       salary_to                 salary_bin  \
# 1110  100001.00  От 100 тысяч до 200 тысяч
#
#                        key_skills_from_key_skills_field  \
# 1110  Аналитика продаж, Конкурентная аналитика, Анал...
#
#      hard_skills_from_description soft_skills_from_description
# 1110                          NaN                          NaN

# %% [markdown]
# [![2024-12-09_02-37-09.png](https://s.iimg.su/s/08/th_y9YLumKBq67pmCV3FNLuRYRy4E2iQ0yLVLM4jz9f.png)](https://iimg.su/i/yBkPm)

# %%
sistem_analysts.query('salary_from < 20000')
# Out:
#             id                              name        published_at  \
# 1470  91944373  Системный Аналитик Middle/Senior 2024-07-06 15:14:38
#
#                        alternate_url      type    employer department    area  \
# 1470  https://hh.ru/vacancy/91944373  Открытая  Datanomica        NaN  Москва
#
#              experience                                         key_skills  \
# 1470  Senior (6+ years)  ['JSON API', 'JSON', 'XML', 'SQL', 'Юнит-эконо...
#
#               schedule        employment  \
# 1470  Удаленная работа  Полная занятость
#
#                                             description  \
# 1470  привет! мы — ооо «датаномика», решаем проблемы...
#
#                                  description_lemmatized  salary_from  \
# 1470  привет датаномика решать проблема структуриров...       280.00
#
#       salary_to        salary_bin  \
# 1470  340000.00  Больше 300 тысяч
#
#                   key_skills_from_key_skills_field  \
# 1470  JSON API, XML, JSON, Agile, Java, SQL, Kafka
#
#      hard_skills_from_description soft_skills_from_description
# 1470   confluence, Юнит-экономика                          NaN

# %% [markdown]
# [![2024-12-09_02-31-41.png](https://s.iimg.su/s/08/th_G0wFNBNawmAV0fmBL2Vqv2aNgtxuZtEu8zjeMu6z.png)](https://iimg.su/i/NchqK)

# %% [markdown]
# Скорее всего имеют место опечатки, думаю, имелись в виду 50 тысяч и 280 тысяч рублей соответственно.

# %%
data_analysts.loc[data_analysts['salary_from'] == 50 , 'salary_from'] = 50000
sistem_analysts.loc[sistem_analysts['salary_from'] == 280 , 'salary_from'] = 280000

display(sistem_analysts.query('id == 91944373'), 
      data_analysts.query('id == 96943446 ')
     )
# Out:
#             id                              name        published_at  \
# 1470  91944373  Системный Аналитик Middle/Senior 2024-07-06 15:14:38
#
#                        alternate_url      type    employer department    area  \
# 1470  https://hh.ru/vacancy/91944373  Открытая  Datanomica        NaN  Москва
#
#              experience                                         key_skills  \
# 1470  Senior (6+ years)  ['JSON API', 'JSON', 'XML', 'SQL', 'Юнит-эконо...
#
#               schedule        employment  \
# 1470  Удаленная работа  Полная занятость
#
#                                             description  \
# 1470  привет! мы — ооо «датаномика», решаем проблемы...
#
#                                  description_lemmatized  salary_from  \
# 1470  привет датаномика решать проблема структуриров...    280000.00
#
#       salary_to        salary_bin  \
# 1470  340000.00  Больше 300 тысяч
#
#                   key_skills_from_key_skills_field  \
# 1470  JSON API, XML, JSON, Agile, Java, SQL, Kafka
#
#      hard_skills_from_description soft_skills_from_description
# 1470   confluence, Юнит-экономика                          NaN
#             id                                               name  \
# 1110  96943446  Аналитик данных в отдел развития на маркетплейсах
#
#             published_at                   alternate_url      type  \
# 1110 2024-05-11 21:45:07  https://hh.ru/vacancy/96943446  Открытая
#
#                       employer department    area             experience  \
# 1110  Репетуев Иван Дмитриевич        NaN  Москва  Junior (no experince)
#
#                                              key_skills          schedule  \
# 1110  ['Аналитическое мышление', 'Аналитика продаж',...  Удаленная работа
#
#             employment                                        description  \
# 1110  Полная занятость  ищу в команду аналитика до глубины мозга косте...
#
#                                  description_lemmatized  salary_from  \
# 1110  искать команда аналитик глубина мозг кость име...     50000.00
#
#       salary_to                 salary_bin  \
# 1110  100001.00  От 100 тысяч до 200 тысяч
#
#                        key_skills_from_key_skills_field  \
# 1110  Аналитика продаж, Конкурентная аналитика, Анал...
#
#      hard_skills_from_description soft_skills_from_description
# 1110                          NaN                          NaN

# %%
data_analysts.nunique()
# Out:
# id                                  1801
# name                                 763
# published_at                        1746
# alternate_url                       1801
# type                                   1
# employer                             690
# department                            86
# area                                  70
# experience                             4
# key_skills                           833
# schedule                               4
# employment                             4
# description                         1460
# description_lemmatized              1429
# salary_from                           70
# salary_to                             65
# salary_bin                             5
# key_skills_from_key_skills_field     774
# hard_skills_from_description           8
# soft_skills_from_description          35
# dtype: int64

# %% [markdown]
# 1. Все id и alternate_url уникальные
# 2. Много уникальных значений в столбцах: description, description_lemmatized, key_skills, key_skills_from_key_skills_field (39.31% пропусков в датасете), name, employer
# 3. Немного уникальных значений: type, department (71.07% пропусков в датасете), area, experience, schedule, employment, salary_from (80.68% пропусков), salary_to (87.34% пропусков), salary_bin, hard_skills_from_description(76.79% пропусков), soft_skills_from_description (67.35%)

# %%
sistem_analysts.nunique()
# Out:
# id                                  1915
# name                                 813
# published_at                        1766
# alternate_url                       1915
# type                                   1
# employer                             836
# department                            75
# area                                  81
# experience                             4
# key_skills                          1080
# schedule                               4
# employment                             4
# description                         1715
# description_lemmatized              1696
# salary_from                           54
# salary_to                             57
# salary_bin                             5
# key_skills_from_key_skills_field    1032
# hard_skills_from_description           4
# soft_skills_from_description          29
# dtype: int64

# %% [markdown]
# 1. Все id и alternate_url уникальные
# 2. Много уникальных значений в столбцах: description, description_lemmatized, key_skills, key_skills_from_key_skills_field (33.47% пропусков в датасете), name, employer
# 3. Немного уникальных значений: type, department (81.15% пропусков в датасете), area, experience, schedule, employment, salary_from (81.41% пропусков), salary_to (85.43% пропусков), salary_bin, hard_skills_from_description(70.23% пропусков), soft_skills_from_description (25.48%)

# %% [markdown]
# Посмотрим на уникальные значения столбцов:

# %%
def uniq_val(df):
    columns_to_check = [
        'type',
        'area',
        'experience',
        'schedule',
        'employment',
        'salary_from',
        'salary_to',
        'salary_bin',
        'hard_skills_from_description',
        'soft_skills_from_description'
    ]

    for column in columns_to_check:
        print(f"Столбец: {column}")
        print("Количество уникальных значений:", df[column].nunique())
        # Отображаем уникальные значения, отсортированные по возрастанию
        print("Уникальные значения:", sorted(df[column].dropna().unique()))
        print("-" * 50)

# %%
uniq_val(data_analysts)
# Out:
# Столбец: type
# Количество уникальных значений: 1
# Уникальные значения: ['Открытая']
# --------------------------------------------------
# Столбец: area
# Количество уникальных значений: 70
# Уникальные значения: ['Адыгейск', 'Алтайское', 'Артем', 'Байбек', 'Балашиха', 'Белгород', 'Вейделевка', 'Великие Луки', 'Вельск', 'Верхняя Пышма', 'Владивосток', 'Владимир', 'Волгоград', 'Воронеж', 'Горно-Алтайск', 'Дзержинский', 'Дмитров', 'Екатеринбург', 'Златоуст', 'Иваново (Ивановская область)', 'Ижевск', 'Иркутск', 'Казань', 'Калининград', 'Кемерово', 'Киров (Кировская область)', 'Королев', 'Краснодар', 'Красноярск', 'Курган', 'Липецк', 'Луховицы', 'Магнитогорск', 'Майкоп', 'Москва', 'Мытищи', 'Набережные Челны', 'Нефтекамск', 'Нижний Новгород', 'Новосибирск', 'Одинцово', 'Омск', 'Оренбург', 'Пермь', 'Подольск (Московская область)', 'Псков', 'Пушкино (Московская область)', 'Ростов-на-Дону', 'Рязань', 'Самара', 'Санкт-Петербург', 'Саратов', 'Северск (Томская область)', 'Симферополь', 'Смоленск', 'Сочи', 'Ступино', 'Тверь', 'Тольятти', 'Томск', 'Тула', 'Турочак', 'Тюмень', 'Ульяновск', 'Уфа', 'Химки', 'Чебоксары', 'Челябинск', 'Щербинка', 'Якутск']
# --------------------------------------------------
# Столбец: experience
# Количество уникальных значений: 4
# Уникальные значения: ['Junior (no experince)', 'Junior+ (1-3 years)', 'Middle (3-6 years)', 'Senior (6+ years)']
# --------------------------------------------------
# Столбец: schedule
# Количество уникальных значений: 4
# Уникальные значения: ['Гибкий график', 'Полный день', 'Сменный график', 'Удаленная работа']
# --------------------------------------------------
# Столбец: employment
# Количество уникальных значений: 4
# Уникальные значения: ['Полная занятость', 'Проектная работа', 'Стажировка', 'Частичная занятость']
# --------------------------------------------------
# Столбец: salary_from
# Количество уникальных значений: 70
# Уникальные значения: [25000.0, 26000.0, 28940.0, 30000.0, 34000.0, 35000.0, 40000.0, 40050.0, 40700.0, 42500.0, 45000.0, 50000.0, 51000.0, 55000.0, 56000.0, 57000.0, 59000.0, 60000.0, 61000.0, 63000.0, 65000.0, 65450.0, 68000.0, 70000.0, 72000.0, 74450.0, 75000.0, 76000.0, 76700.0, 78000.0, 78045.0, 80000.0, 81000.0, 84000.0, 85000.0, 86560.0, 90000.0, 95000.0, 99500.0, 100000.0, 103000.0, 105000.0, 107000.0, 108000.0, 110000.0, 112200.0, 115000.0, 120000.0, 123000.0, 130000.0, 135000.0, 136000.0, 137000.0, 140000.0, 150000.0, 160000.0, 180000.0, 187000.0, 190000.0, 200000.0, 210000.0, 233750.0, 250000.0, 257125.0, 280500.0, 299200.0, 300000.0, 345950.0, 350000.0, 398000.0]
# --------------------------------------------------
# Столбец: salary_to
# Количество уникальных значений: 65
# Уникальные значения: [25000.0, 26000.0, 30000.0, 35000.0, 36175.0, 40000.0, 40700.0, 50000.0, 55000.0, 56000.0, 60000.0, 65000.0, 69000.0, 70000.0, 72000.0, 74800.0, 75000.0, 78045.0, 80000.0, 84700.0, 85000.0, 86560.0, 90000.0, 92000.0, 98000.0, 99500.0, 100000.0, 100001.0, 101000.0, 107000.0, 110000.0, 114000.0, 120000.0, 122400.0, 126500.0, 130000.0, 136000.0, 140000.0, 142000.0, 145000.0, 150000.0, 160000.0, 170000.0, 180000.0, 182000.0, 185000.0, 200000.0, 210000.0, 218400.0, 220000.0, 230000.0, 234000.0, 250000.0, 255000.0, 260000.0, 280000.0, 280500.0, 298000.0, 300000.0, 350000.0, 400000.0, 420750.0, 467500.0, 495550.0, 497500.0]
# --------------------------------------------------
# Столбец: salary_bin
# Количество уникальных значений: 5
# Уникальные значения: ['Больше 300 тысяч', 'ЗП не указана', 'Меньше 100 тысяч', 'От 100 тысяч до 200 тысяч', 'От 200 тысяч до 300 тысяч']
# --------------------------------------------------
# Столбец: hard_skills_from_description
# Количество уникальных значений: 8
# Уникальные значения: ['Google Sheets', 'Pandas', 'Pandas, Google Sheets', 'Pandas, confluence', 'Pandas, Юнит-экономика', 'confluence', 'Математическая статистика', 'Юнит-экономика']
# --------------------------------------------------
# Столбец: soft_skills_from_description
# Количество уникальных значений: 35
# Уникальные значения: ['Адаптивность', 'Аналитическое мышление', 'Документация', 'Документация, Аналитическое мышление', 'Документация, Переговоры', 'Документация, Проактивность', 'Документация, Проактивность, Креативность', 'Документация, Проактивность, Переговоры', 'Коммуникация', 'Коммуникация, Адаптивность', 'Коммуникация, Аналитическое мышление', 'Коммуникация, Документация', 'Коммуникация, Документация, Аналитическое мышление', 'Коммуникация, Документация, Переговоры', 'Коммуникация, Документация, Презентация результатов', 'Коммуникация, Документация, Проактивность', 'Коммуникация, Документация, Проактивность, Аналитическое мышление', 'Коммуникация, Критическое мышление', 'Коммуникация, Переговоры', 'Коммуникация, Переговоры, Аналитическое мышление', 'Коммуникация, Проактивность', 'Коммуникация, Решение проблем', 'Коммуникация, Решение проблем, Критическое мышление, Внимание к деталям', 'Коммуникация, Решение проблем, Презентация результатов, Внимание к деталям', 'Коммуникация, Тайм-менеджмент, Креативность, Аналитическое мышление', 'Креативность', 'Креативность, Аналитическое мышление', 'Переговоры', 'Принятие решений', 'Проактивность', 'Проактивность, Аналитическое мышление', 'Решение проблем', 'Решение проблем, Принятие решений', 'Тайм-менеджмент', 'Эмпатия']
# --------------------------------------------------

# %%
print("Самая ранняя дата публикации:", data_analysts['published_at'].min().date(), '\n' 
    "Самая поздняя дата публикации:", data_analysts['published_at'].max().date())
# Out:
# Самая ранняя дата публикации: 2024-02-13
# Самая поздняя дата публикации: 2024-06-11

# %%
uniq_val(sistem_analysts)
# Out:
# Столбец: type
# Количество уникальных значений: 1
# Уникальные значения: ['Открытая']
# --------------------------------------------------
# Столбец: area
# Количество уникальных значений: 81
# Уникальные значения: ['Абакан', 'Адлер', 'Апатиты', 'Астрахань', 'Барнаул', 'Белгород', 'Белорецк', 'Брянск', 'Владивосток', 'Владимир', 'Волгоград', 'Вологда', 'Воронеж', 'Геленджик', 'Дзержинск (Нижегородская область)', 'Дубна', 'Екатеринбург', 'Иваново (Ивановская область)', 'Ижевск', 'Иннополис', 'Иркутск', 'Йошкар-Ола', 'Казань', 'Калининград', 'Калуга', 'Кемерово', 'Киров (Кировская область)', 'Кольчугино', 'Королев', 'Кострома', 'Красногорск', 'Краснодар', 'Красноярск', 'Курган', 'Курск', 'Липецк', 'Магнитогорск', 'Майкоп', 'Москва', 'Муром', 'Мытищи', 'Набережные Челны', 'Нижний Новгород', 'Новокузнецк', 'Новосибирск', 'Новочеркасск', 'Омск', 'Орел', 'Оренбург', 'Пенза', 'Пермь', 'Петрозаводск', 'Подольск (Московская область)', 'Ростов-на-Дону', 'Рубцовск', 'Рязань', 'Самара', 'Санкт-Петербург', 'Саранск', 'Саратов', 'Севастополь', 'Смоленск', 'Сочи', 'Ставрополь', 'Сургут', 'Таганрог', 'Тамбов', 'Тверь', 'Тольятти', 'Томск', 'Тула', 'Тюмень', 'Улан-Удэ', 'Ульяновск', 'Уфа', 'Хабаровск', 'Хасавюрт', 'Чебоксары', 'Челябинск', 'Череповец', 'Ярославль']
# --------------------------------------------------
# Столбец: experience
# Количество уникальных значений: 4
# Уникальные значения: ['Junior (no experince)', 'Junior+ (1-3 years)', 'Middle (3-6 years)', 'Senior (6+ years)']
# --------------------------------------------------
# Столбец: schedule
# Количество уникальных значений: 4
# Уникальные значения: ['Гибкий график', 'Полный день', 'Сменный график', 'Удаленная работа']
# --------------------------------------------------
# Столбец: employment
# Количество уникальных значений: 4
# Уникальные значения: ['Полная занятость', 'Проектная работа', 'Стажировка', 'Частичная занятость']
# --------------------------------------------------
# Столбец: salary_from
# Количество уникальных значений: 54
# Уникальные значения: [20000.0, 30000.0, 35000.0, 35500.0, 40000.0, 43000.0, 45000.0, 46000.0, 50000.0, 50200.0, 50600.0, 59000.0, 60000.0, 70000.0, 75000.0, 76000.0, 78000.0, 80000.0, 83000.0, 85000.0, 90000.0, 100000.0, 105000.0, 115000.0, 120000.0, 128000.0, 130000.0, 140000.0, 150000.0, 152000.0, 160000.0, 170000.0, 172413.0, 180000.0, 189500.0, 190000.0, 195000.0, 200000.0, 208818.0, 220000.0, 230000.0, 233000.0, 233750.0, 240000.0, 245000.0, 250000.0, 257000.0, 260000.0, 261800.0, 270000.0, 280000.0, 290000.0, 300000.0, 350000.0]
# --------------------------------------------------
# Столбец: salary_to
# Количество уникальных значений: 57
# Уникальные значения: [20000.0, 25000.0, 40000.0, 43000.0, 50000.0, 60000.0, 70000.0, 75000.0, 80000.0, 83000.0, 90000.0, 92000.0, 100000.0, 110000.0, 115000.0, 120000.0, 128000.0, 130000.0, 140000.0, 150000.0, 150800.0, 160000.0, 170000.0, 174000.0, 180000.0, 195000.0, 200000.0, 210000.0, 220000.0, 225000.0, 230000.0, 240000.0, 250000.0, 260000.0, 270000.0, 280000.0, 284000.0, 290000.0, 300000.0, 310000.0, 312000.0, 330000.0, 340000.0, 342000.0, 345000.0, 350000.0, 359000.0, 370000.0, 380000.0, 400000.0, 402299.0, 413670.0, 418000.0, 420000.0, 450000.0, 500000.0, 580000.0]
# --------------------------------------------------
# Столбец: salary_bin
# Количество уникальных значений: 5
# Уникальные значения: ['Больше 300 тысяч', 'ЗП не указана', 'Меньше 100 тысяч', 'От 100 тысяч до 200 тысяч', 'От 200 тысяч до 300 тысяч']
# --------------------------------------------------
# Столбец: hard_skills_from_description
# Количество уникальных значений: 4
# Уникальные значения: ['Pandas', 'confluence', 'confluence, Юнит-экономика', 'Юнит-экономика']
# --------------------------------------------------
# Столбец: soft_skills_from_description
# Количество уникальных значений: 29
# Уникальные значения: ['Аналитическое мышление', 'Документация', 'Документация, Аналитическое мышление', 'Документация, Креативность', 'Документация, Креативность, Аналитическое мышление', 'Документация, Переговоры', 'Документация, Переговоры, Аналитическое мышление', 'Документация, Проактивность', 'Документация, Проактивность, Аналитическое мышление', 'Документация, Проактивность, Креативность', 'Документация, Проактивность, Переговоры', 'Документация, Эмпатия, Аналитическое мышление', 'Коммуникация', 'Коммуникация, Аналитическое мышление', 'Коммуникация, Документация', 'Коммуникация, Документация, Аналитическое мышление', 'Коммуникация, Документация, Креативность', 'Коммуникация, Документация, Переговоры', 'Коммуникация, Документация, Проактивность', 'Коммуникация, Документация, Проактивность, Переговоры', 'Коммуникация, Переговоры', 'Коммуникация, Письменная коммуникация, Документация', 'Коммуникация, Проактивность', 'Коммуникация, Проактивность, Креативность', 'Переговоры', 'Проактивность', 'Проактивность, Аналитическое мышление', 'Тайм-менеджмент, Документация', 'Тайм-менеджмент, Документация, Проактивность, Переговоры, Аналитическое мышление']
# --------------------------------------------------

# %%
print("Самая ранняя дата публикации:", sistem_analysts['published_at'].min().date(), '\n' 
    "Самая поздняя дата публикации:", sistem_analysts['published_at'].max().date())
# Out:
# Самая ранняя дата публикации: 2024-06-27
# Самая поздняя дата публикации: 2024-07-09

# %% [markdown]
# ### Работа с дубликатами  <a id="chapter3"></a>

# %%
data_analysts[data_analysts.duplicated(subset=['id'], keep=False)] \
.sort_values(by=['name', 'employer'])
# Out:
# Empty DataFrame
# Columns: [id, name, published_at, alternate_url, type, employer, department, area, experience, key_skills, schedule, employment, description, description_lemmatized, salary_from, salary_to, salary_bin, key_skills_from_key_skills_field, hard_skills_from_description, soft_skills_from_description]
# Index: []

# %%
sistem_analysts[sistem_analysts.duplicated(subset=['id'], keep=False)] \
.sort_values(by=['name', 'employer'])
# Out:
# Empty DataFrame
# Columns: [id, name, published_at, alternate_url, type, employer, department, area, experience, key_skills, schedule, employment, description, description_lemmatized, salary_from, salary_to, salary_bin, key_skills_from_key_skills_field, hard_skills_from_description, soft_skills_from_description]
# Index: []

# %% [markdown]
# Так как все id вакансий уникальные, посмотрим на дубликаты по всем столбцам, кроме id, ссылки и даты публикации.

# %%
columns_list = [
    'name', 
    'employer', 
    'department', 
    'area', 
    'experience'
]

# %%
data_analysts[data_analysts.duplicated(subset=columns_list)] \
.sort_values(by=['name', 'employer'])
# Out:
#             id                                               name  \
# 1439  98305174        BI-Аналитик/Бизнес-Аналитик/Аналитик данных
# 909   95919755       BI-аналитик / Data Analyst / Аналитик данных
# 1408  98088004                       BI-аналитик/ Аналитик данных
# 1296  97631655                                       Data Analyst
# 1793  99973972                                       Data Analyst
# ...        ...                                                ...
# 1459  98390875           Старший аналитик данных (Data Scientist)
# 1030  96494928                Старший аналитик данных (маркетинг)
# 1747  99737480                              Урбан-аналитик данных
# 1656  99141448  Эксперт по цифровым технологиям аудита (Data A...
# 1777  99869022  Эксперт-аналитик данных в группу цифрового аудита
#
#             published_at                   alternate_url      type  \
# 1439 2024-05-12 10:03:19  https://hh.ru/vacancy/98305174  Открытая
# 909  2024-04-23 11:41:29  https://hh.ru/vacancy/95919755  Открытая
# 1408 2024-05-12 17:09:30  https://hh.ru/vacancy/98088004  Открытая
# 1296 2024-04-22 14:47:42  https://hh.ru/vacancy/97631655  Открытая
# 1793 2024-05-23 16:28:59  https://hh.ru/vacancy/99973972  Открытая
# ...                  ...                             ...       ...
# 1459 2024-05-04 16:33:29  https://hh.ru/vacancy/98390875  Открытая
# 1030 2024-04-09 09:38:57  https://hh.ru/vacancy/96494928  Открытая
# 1747 2024-06-08 17:13:09  https://hh.ru/vacancy/99737480  Открытая
# 1656 2024-05-16 12:03:05  https://hh.ru/vacancy/99141448  Открытая
# 1777 2024-05-22 18:35:43  https://hh.ru/vacancy/99869022  Открытая
#
#                                             employer              department  \
# 1439                                         Гоудрон                     NaN
# 909   Федеральная сеть книжных магазинов Читай-город                     NaN
# 1408                                          Сэлвим                     NaN
# 1296                         Finstar Financial Group                     NaN
# 1793                         Finstar Financial Group                     NaN
# ...                                              ...                     ...
# 1459                                   Газпром нефть  ПАО «Газпром нефть» ИТ
# 1030                                            Ozon   Ozon Офис и Коммерция
# 1747                                           Mayak                     NaN
# 1656                                            СБЕР      Сбер для экспертов
# 1777                    Recruitment Boutique S.M.Art                     NaN
#
#                  area           experience  \
# 1439           Москва  Junior+ (1-3 years)
# 909            Москва  Junior+ (1-3 years)
# 1408           Москва  Junior+ (1-3 years)
# 1296           Москва  Junior+ (1-3 years)
# 1793           Москва  Junior+ (1-3 years)
# ...               ...                  ...
# 1459  Санкт-Петербург  Junior+ (1-3 years)
# 1030           Москва   Middle (3-6 years)
# 1747           Москва  Junior+ (1-3 years)
# 1656  Санкт-Петербург  Junior+ (1-3 years)
# 1777           Москва  Junior+ (1-3 years)
#
#                                              key_skills          schedule  \
# 1439  ['Анализ данных', 'SQL', 'Работа с большим объ...       Полный день
# 909      ['MS SQL', 'Анализ данных', 'SQL', 'MS Excel']  Удаленная работа
# 1408                                         ['Pandas']       Полный день
# 1296    ['confluence', 'Python', 'Документация', 'SQL']       Полный день
# 1793    ['confluence', 'Python', 'Документация', 'SQL']       Полный день
# ...                                                 ...               ...
# 1459                                                 []       Полный день
# 1030  ['SQL', 'Python', 'Маркетинг, реклама, PR', 'М...  Удаленная работа
# 1747  ['Английский язык', 'Анализ данных', 'Девелопм...       Полный день
# 1656  ['Анализ данных', 'SQL', 'Python', 'Hadoop', '...       Полный день
# 1777                      ['Аудит', 'Python', 'MS SQL']       Полный день
#
#                employment                                        description  \
# 1439     Полная занятость  привет, уважаемые соискатели! мы, компания, &q...
# 909      Полная занятость  привет! мы команда ит компании &quot;читай тех...
# 1408     Полная занятость  обязанности:  сбор бизнес-требований от внутре...
# 1296     Полная занятость  finstar financial group – крупный международны...
# 1793     Полная занятость  finstar financial group – крупный международны...
# ...                   ...                                                ...
# 1459     Полная занятость  мы – команда «газпромнефть – цифровые решения»...
# 1030     Полная занятость  чем предстоит заниматься:  отслеживать и собир...
# 1747  Частичная занятость  обязанности: • анализ рынка/субрынков коммерче...
# 1656     Полная занятость  приглашаем присоединиться к команде отдела ауд...
# 1777     Полная занятость  ищем эксперта со знанием инструментов анализа ...
#
#                                  description_lemmatized  salary_from  \
# 1439  привет уважаемый соискатель компания quot godr...    100000.00
# 909   привет команда ита компания quot читать технол...          NaN
# 1408  обязанность сбор бизнес требование внутренний ...          NaN
# 1296  finstar financial group крупный международный ...          NaN
# 1793  finstar financial group крупный международный ...    187000.00
# ...                                                 ...          ...
# 1459  команда газпромнефть цифровой решение часть ит...          NaN
# 1030  предстоять заниматься отслеживать собирать раз...          NaN
# 1747  обязанность анализ рынок субрынок коммерческий...    100000.00
# 1656  приглашать присоединяться команда отдел аудит ...          NaN
# 1777  искать эксперт знание инструмент анализ данные...          NaN
#
#       salary_to                 salary_bin  \
# 1439        NaN              ЗП не указана
# 909         NaN              ЗП не указана
# 1408        NaN              ЗП не указана
# 1296        NaN              ЗП не указана
# 1793  280500.00  От 200 тысяч до 300 тысяч
# ...         ...                        ...
# 1459        NaN              ЗП не указана
# 1030        NaN              ЗП не указана
# 1747        NaN              ЗП не указана
# 1656        NaN              ЗП не указана
# 1777        NaN              ЗП не указана
#
#                        key_skills_from_key_skills_field  \
# 1439  SQL, Аналитика, Анализ данных, Базы данных, Ра...
# 909                MS SQL, SQL, Анализ данных, MS Excel
# 1408                                                NaN
# 1296                                        Python, SQL
# 1793                                        Python, SQL
# ...                                                 ...
# 1459                                                NaN
# 1030  Маркетинг, реклама, PR, аналитика данных, Pyth...
# 1747  Маркетинговый анализ, Английский язык, GIS, Та...
# 1656                 SQL, Python, Hadoop, Анализ данных
# 1777                              Аудит, MS SQL, Python
#
#      hard_skills_from_description soft_skills_from_description
# 1439                          NaN                          NaN
# 909                           NaN                          NaN
# 1408                       Pandas                          NaN
# 1296                   confluence                 Документация
# 1793                   confluence                 Документация
# ...                           ...                          ...
# 1459                          NaN                          NaN
# 1030                       Pandas                          NaN
# 1747                          NaN              Тайм-менеджмент
# 1656                          NaN                   Переговоры
# 1777                          NaN                          NaN
#
# [390 rows x 20 columns]

# %%
len(data_analysts[data_analysts.duplicated(subset=columns_list)] \
.sort_values(by=['name', 'employer']))/ len(data_analysts)*100
# Out:
# 21.654636313159354

# %% [markdown]
# Также и для системных аналитиков

# %%
sistem_analysts[sistem_analysts.duplicated(subset=columns_list)] \
.sort_values(by=['name', 'employer'])
# Out:
#              id                                               name  \
# 1012  103277921                                     System Analyst
# 710   103031056                System Analyst / Системный аналитик
# 730   103039294                System Analyst / Системный аналитик
# 991   103246914                System Analyst / Системный аналитик
# 1680   96840588                System analyst / Системный аналитик
# ...         ...                                                ...
# 661   102941659                  Системный аналитик (кредитование)
# 1702   97290524                    Системный аналитик 1С (Обучаем)
# 156   101369907  Системный аналитик проекта по созданию и разви...
# 82    101092259                         Старший системный аналитик
# 608   102909202                         Старший системный аналитик
#
#             published_at                    alternate_url      type  \
# 1012 2024-07-04 11:14:26  https://hh.ru/vacancy/103277921  Открытая
# 710  2024-07-01 10:52:04  https://hh.ru/vacancy/103031056  Открытая
# 730  2024-07-01 12:09:36  https://hh.ru/vacancy/103039294  Открытая
# 991  2024-07-03 22:35:38  https://hh.ru/vacancy/103246914  Открытая
# 1680 2024-07-05 16:01:02   https://hh.ru/vacancy/96840588  Открытая
# ...                  ...                              ...       ...
# 661  2024-06-28 17:56:00  https://hh.ru/vacancy/102941659  Открытая
# 1702 2024-07-08 09:17:47   https://hh.ru/vacancy/97290524  Открытая
# 156  2024-07-03 13:08:49  https://hh.ru/vacancy/101369907  Открытая
# 82   2024-07-01 09:45:27  https://hh.ru/vacancy/101092259  Открытая
# 608  2024-06-28 11:06:48  https://hh.ru/vacancy/102909202  Открытая
#
#                                              employer  \
# 1012                                             АТОМ
# 710                                             Aston
# 730                                             Aston
# 991                                             Aston
# 1680                                             АТОМ
# ...                                               ...
# 661                                              СБЕР
# 1702                   Компания Апогей (1С-франчайзи)
# 156                                                Т1
# 82    БФТ-Холдинг (Бюджетные и Финансовые Технологии)
# 608   БФТ-Холдинг (Бюджетные и Финансовые Технологии)
#
#                        department             area             experience  \
# 1012                          NaN           Москва     Middle (3-6 years)
# 710                           NaN           Москва     Middle (3-6 years)
# 730                           NaN          Воронеж     Middle (3-6 years)
# 991                           NaN  Санкт-Петербург    Junior+ (1-3 years)
# 1680                          NaN  Санкт-Петербург     Middle (3-6 years)
# ...                           ...              ...                    ...
# 661                      Сбер. IT           Москва     Middle (3-6 years)
# 1702                          NaN     Екатеринбург  Junior (no experince)
# 156   ГК Иннотех | Большие данные           Москва     Middle (3-6 years)
# 82                            NaN           Москва     Middle (3-6 years)
# 608                           NaN           Москва     Middle (3-6 years)
#
#                                              key_skills          schedule  \
# 1012                                   ['Документация']       Полный день
# 710   ['Apache Kafka', 'REST', 'SQL', 'SOAP', 'UML',...       Полный день
# 730                                      ['confluence']  Удаленная работа
# 991              ['UML', 'Документация', 'REST', 'SQL']  Удаленная работа
# 1680                                   ['Документация']       Полный день
# ...                                                 ...               ...
# 661                                      ['confluence']       Полный день
# 1702                                                 []       Полный день
# 156   ['SQL', 'Анализ данных', 'Переговоры', 'Докуме...       Полный день
# 82                       ['confluence', 'Документация']       Полный день
# 608   ['REST', 'XML', 'Atlassian Jira', 'SQL', 'Доку...       Полный день
#
#             employment                                        description  \
# 1012  Полная занятость  мы — атом. разрабатываем электромобиль-гаджет ...
# 710   Полная занятость  заказчик входит в топ-10 российских банков по ...
# 730   Полная занятость  мы – аутсорсинговая it-компания aston, разраба...
# 991   Полная занятость  мы – аутсорсинговая it-компания aston, разраба...
# 1680  Полная занятость  мы — атом. разрабатываем электромобиль-гаджет ...
# ...                ...                                                ...
# 661   Полная занятость  команда трайба &quot;малый и микро бизнес&quot...
# 1702  Полная занятость  системный аналитик 1с (обучаем) наши клиенты –...
# 156   Полная занятость  ​​​ищем энергичного системного-аналитика проек...
# 82    Полная занятость  бфт-холдинг (входит в группу компаний «ростеле...
# 608   Полная занятость  компания «бюджетные финансовые технологии» (бф...
#
#                                  description_lemmatized  salary_from  \
# 1012  атом разрабатывать электромобиль гаджет версия...          NaN
# 710   заказчик входить топ 1 российский банк величин...          NaN
# 730   аутсорсинговый it компания aston разрабатывать...          NaN
# 991   аутсорсинговый it компания aston разрабатывать...          NaN
# 1680  атом разрабатывать электромобиль гаджет версия...          NaN
# ...                                                 ...          ...
# 661   команда трайба quot малый микро бизнес quot ра...          NaN
# 1702  системный аналитик 1с обучать наш клиент бухга...     40000.00
# 156   искать энергичный системный аналитик проект со...          NaN
# 82    бфт холдинг входить группа компания ростелеком...          NaN
# 608   компания бюджетный финансовый технология бфт з...          NaN
#
#       salary_to        salary_bin  \
# 1012        NaN     ЗП не указана
# 710         NaN     ЗП не указана
# 730         NaN     ЗП не указана
# 991         NaN     ЗП не указана
# 1680        NaN     ЗП не указана
# ...         ...               ...
# 661         NaN     ЗП не указана
# 1702   70000.00  Меньше 100 тысяч
# 156         NaN     ЗП не указана
# 82          NaN     ЗП не указана
# 608         NaN     ЗП не указана
#
#                        key_skills_from_key_skills_field  \
# 1012                                                NaN
# 710            SQL, SOAP, REST, Apache Kafka, UML, BPMN
# 730                                                 NaN
# 991                                      REST, UML, SQL
# 1680                                                NaN
# ...                                                 ...
# 661                                                 NaN
# 1702                                                NaN
# 156   SQL, Проектная документация, Техническая докум...
# 82                                                  NaN
# 608   BPMN, Atlassian Jira, PostgreSQL, XML, REST, U...
#
#      hard_skills_from_description             soft_skills_from_description
# 1012                          NaN                             Документация
# 710                           NaN                                      NaN
# 730                    confluence                                      NaN
# 991                           NaN                             Документация
# 1680                          NaN                             Документация
# ...                           ...                                      ...
# 661                    confluence                                      NaN
# 1702                          NaN                                      NaN
# 156                           NaN  Документация, Проактивность, Переговоры
# 82                     confluence                             Документация
# 608                    confluence                             Документация
#
# [78 rows x 20 columns]

# %%
len(sistem_analysts[sistem_analysts.duplicated(subset=columns_list)] \
.sort_values(by=['name', 'employer'])) / len(sistem_analysts)*100
# Out:
# 4.073107049608355

# %% [markdown]
# Удалить 21% данных мы не можем. У системных аналитиков доля возможных дубликатов менее 5%, но даже в этом срезе содержаться ключевые данные для дальнейшего исследования (например зарплатные данные, доля пропусков в которых от 81% до 85%).
# Поэтому пометим данные как возможные дубликаты. Будем считать, что дубликатами являются более "старые" по дате опубликования вакансии.

# %%
data_analysts = data_analysts.sort_values(by='published_at', ascending=False)

data_analysts['duplicates'] = data_analysts.duplicated(subset=columns_list, keep='first') \
.replace({True: 'возможный дубликат', False: ''})

data_analysts[data_analysts.duplicated(subset=columns_list, keep=False)] \
.sort_values(by=[
    'name', 
    'employer', 
    'department', 
    'area', 
    'experience'
])[[
    'published_at',
    'name', 
    'employer', 
    'department', 
    'area', 
    'experience', 
    'duplicates'
]].head(10)
# Out:
#             published_at                                          name  \
# 215  2024-06-10 13:42:00   BI-Аналитик/Бизнес-Аналитик/Аналитик данных
# 1439 2024-05-12 10:03:19   BI-Аналитик/Бизнес-Аналитик/Аналитик данных
# 228  2024-06-04 18:25:08  BI-аналитик / Data Analyst / Аналитик данных
# 909  2024-04-23 11:41:29  BI-аналитик / Data Analyst / Аналитик данных
# 72   2024-06-09 10:00:29                  BI-аналитик/ Аналитик данных
# 1408 2024-05-12 17:09:30                  BI-аналитик/ Аналитик данных
# 1793 2024-05-23 16:28:59                                  Data Analyst
# 1296 2024-04-22 14:47:42                                  Data Analyst
# 1010 2024-04-14 12:06:20                                  Data Analyst
# 1728 2024-05-21 10:56:53                                  Data Analyst
#
#                                             employer department    area  \
# 215                                          Гоудрон        NaN  Москва
# 1439                                         Гоудрон        NaN  Москва
# 228   Федеральная сеть книжных магазинов Читай-город        NaN  Москва
# 909   Федеральная сеть книжных магазинов Читай-город        NaN  Москва
# 72                                            Сэлвим        NaN  Москва
# 1408                                          Сэлвим        NaN  Москва
# 1793                         Finstar Financial Group        NaN  Москва
# 1296                         Finstar Financial Group        NaN  Москва
# 1010                         Finstar Financial Group        NaN  Москва
# 1728                            INSITECH Development        NaN  Москва
#
#                experience          duplicates
# 215   Junior+ (1-3 years)
# 1439  Junior+ (1-3 years)  возможный дубликат
# 228   Junior+ (1-3 years)
# 909   Junior+ (1-3 years)  возможный дубликат
# 72    Junior+ (1-3 years)
# 1408  Junior+ (1-3 years)  возможный дубликат
# 1793  Junior+ (1-3 years)
# 1296  Junior+ (1-3 years)  возможный дубликат
# 1010  Junior+ (1-3 years)  возможный дубликат
# 1728   Middle (3-6 years)

# %%
sistem_analysts = sistem_analysts.sort_values(by='published_at', ascending=False)

sistem_analysts['duplicates'] = sistem_analysts.duplicated(subset=columns_list, keep='first') \
.replace({True: 'возможный дубликат', False: ''})

sistem_analysts[sistem_analysts.duplicated(subset=columns_list, keep=False)] \
.sort_values(by=[
    'name', 
    'employer', 
    'department', 
    'area', 
    'experience'
])[[
    'published_at',
    'name', 
    'employer', 
    'department', 
    'area', 
    'experience', 
    'duplicates'
]].head(10)
# Out:
#             published_at                                 name employer  \
# 206  2024-07-06 10:53:13                       System Analyst     АТОМ
# 1012 2024-07-04 11:14:26                       System Analyst     АТОМ
# 252  2024-07-03 13:12:28  System Analyst / Системный аналитик    Aston
# 730  2024-07-01 12:09:36  System Analyst / Системный аналитик    Aston
# 85   2024-07-03 11:18:11  System Analyst / Системный аналитик    Aston
# 710  2024-07-01 10:52:04  System Analyst / Системный аналитик    Aston
# 991  2024-07-03 22:35:38  System Analyst / Системный аналитик    Aston
# 512  2024-06-27 10:21:10  System Analyst / Системный аналитик    Aston
# 205  2024-07-06 10:53:09  System analyst / Системный аналитик     АТОМ
# 1680 2024-07-05 16:01:02  System analyst / Системный аналитик     АТОМ
#
#      department             area           experience          duplicates
# 206         NaN           Москва   Middle (3-6 years)
# 1012        NaN           Москва   Middle (3-6 years)  возможный дубликат
# 252         NaN          Воронеж   Middle (3-6 years)
# 730         NaN          Воронеж   Middle (3-6 years)  возможный дубликат
# 85          NaN           Москва   Middle (3-6 years)
# 710         NaN           Москва   Middle (3-6 years)  возможный дубликат
# 991         NaN  Санкт-Петербург  Junior+ (1-3 years)
# 512         NaN  Санкт-Петербург  Junior+ (1-3 years)  возможный дубликат
# 205         NaN  Санкт-Петербург   Middle (3-6 years)
# 1680        NaN  Санкт-Петербург   Middle (3-6 years)  возможный дубликат

# %% [markdown]
# Можно выделить несколько возможных причин появления дубликатов вакансий:
#
# **1. Разные названия для одной вакансии**
# Например, одна и та же позиция может быть названа по-разному: "Аналитик данных" и "Junior аналитик данных".
# Причина: Вакансия размещена разными рекрутерами, у которых нет единого стандарта наименования.
# **2. Повторная публикация**
# Компания может публиковать одну и ту же вакансию несколько раз, чтобы привлечь больше кандидатов.
# Причина: Повторные публикации для повышения видимости вакансии в поиске
# **3. Изменение условий или описания**
# Вакансии могут быть дублированы с изменением зарплаты, ключевых навыков, опыта или описания.
# Причина: Актуализация данных работодателем.
# **4. Разные рекрутеры или агентства**
# Один и тот же работодатель может поручить поиск сотрудников нескольким рекрутерам или агентствам.
# Причина: Делегирование найма внешним партнерам.

# %% [markdown]
# Теперь, когда установили флаги возможных дубликатов, можно приступить к объединению таблиц, но для начала все же пометим датасеты отдельно.

# %%
data_analysts['dataset_type'] = 'da'
sistem_analysts['dataset_type'] ='sa'
display(data_analysts.head(), sistem_analysts.head())
# Out:
#              id                                               name  \
# 338   101746482                                      Дата аналитик
# 1111   96969442         Аналитик данных в команду Рейнджеры (M+/S)
# 1579   98824646  Аналитик данных в команду Обработки данных (Te...
# 571    94290887          Ведущий аналитик данных (бизнес-аналитик)
# 12    100080002                Продуктовый аналитик / Data Analyst
#
#             published_at                    alternate_url      type  \
# 338  2024-06-11 15:07:30  https://hh.ru/vacancy/101746482  Открытая
# 1111 2024-06-11 14:52:27   https://hh.ru/vacancy/96969442  Открытая
# 1579 2024-06-11 14:47:12   https://hh.ru/vacancy/98824646  Открытая
# 571  2024-06-11 14:36:37   https://hh.ru/vacancy/94290887  Открытая
# 12   2024-06-11 14:34:15  https://hh.ru/vacancy/100080002  Открытая
#
#          employer                         department          area  \
# 338        RUTUBE                                NaN        Москва
# 1111       Контур                                NaN  Екатеринбург
# 1579       Контур                                NaN  Екатеринбург
# 571   Спортмастер  Компания «СПОРТМАСТЕР», Логистика      Балашиха
# 12      Photo Lab                                NaN        Москва
#
#                experience                                         key_skills  \
# 338    Middle (3-6 years)  ['SQL', 'WEB аналитика', 'Clickhouse', 'Яндекс...
# 1111   Middle (3-6 years)  ['Power BI', 'Python', 'SQL', 'Математическое ...
# 1579   Middle (3-6 years)  ['MS SQL', 'Анализ данных', 'Управление команд...
# 571   Junior+ (1-3 years)  ['Анализ данных', 'SQL', 'Power BI', 'Аналитик...
# 12    Junior+ (1-3 years)  ['Linux', 'SQL', 'поведение пользователей', 'D...
#
#               schedule        employment  \
# 338        Полный день  Полная занятость
# 1111  Удаленная работа  Полная занятость
# 1579  Удаленная работа  Полная занятость
# 571        Полный день  Полная занятость
# 12    Удаленная работа  Полная занятость
#
#                                             description  \
# 338   rutube - крупнейший российский видеохостинг, г...
# 1111  контур — экосистема продуктов для бизнеса. мы ...
# 1579  команда состоит из разработчиков баз данных sq...
# 571   отдел отчетности и контроллинга приглашаем ана...
# 12    making mobile photo editing available to anyon...
#
#                                  description_lemmatized  salary_from  \
# 338   rutube крупный российский видеохостинг собират...          NaN
# 1111  контур экосистема продукт бизнес создавать реш...          NaN
# 1579  команда состоять разработчик база данные sql а...          NaN
# 571   отдел отчетность контроллинг приглашать аналит...          NaN
# 12    making mobile photo editing available to anyon...    135000.00
#
#       salary_to                 salary_bin  \
# 338         NaN              ЗП не указана
# 1111        NaN              ЗП не указана
# 1579        NaN              ЗП не указана
# 571         NaN              ЗП не указана
# 12    185000.00  От 100 тысяч до 200 тысяч
#
#                        key_skills_from_key_skills_field  \
# 338   SQL, WEB аналитика, Аналитическое мышление, Ян...
# 1111  SQL, Python, Power BI, Математическое моделиро...
# 1579  Написание документации для пользователей, Разр...
# 571   SQL, Базы данных, Аналитика, Аналитическое мыш...
# 12    SQL, PostgreSQL, Python, MS Excel, LTV, AppsFl...
#
#      hard_skills_from_description soft_skills_from_description duplicates  \
# 338                           NaN                          NaN
# 1111                          NaN                          NaN
# 1579                       Pandas                 Документация
# 571                           NaN                          NaN
# 12                         Pandas                          NaN
#
#      dataset_type
# 338            da
# 1111           da
# 1579           da
# 571            da
# 12             da
#              id                                         name  \
# 1334  103584669       Системный аналитик (банковский проект)
# 235   101646657                           Системный аналитик
# 1333  103583874  Системный аналитик middle / senior удаленно
# 1332  103583776                           Системный аналитик
# 437   102585796                         Аналитик (системный)
#
#             published_at                    alternate_url      type  \
# 1334 2024-07-09 12:47:11  https://hh.ru/vacancy/103584669  Открытая
# 235  2024-07-09 12:41:49  https://hh.ru/vacancy/101646657  Открытая
# 1333 2024-07-09 12:38:43  https://hh.ru/vacancy/103583874  Открытая
# 1332 2024-07-09 12:37:22  https://hh.ru/vacancy/103583776  Открытая
# 437  2024-07-09 12:37:06  https://hh.ru/vacancy/102585796  Открытая
#
#                                 employer department             area  \
# 1334                          Volna.tech        NaN  Санкт-Петербург
# 235                        СберМаркетинг        NaN           Москва
# 1333                       MKomov Studio        NaN     Петрозаводск
# 1332  Научно-Производственный Центр Макс        NaN           Москва
# 437                              SL Soft        NaN           Москва
#
#                experience                                         key_skills  \
# 1334   Middle (3-6 years)  ['MS SQL', 'SQL', 'интеграции', 'Документация'...
# 235    Middle (3-6 years)                                   ['Документация']
# 1333  Junior+ (1-3 years)  ['Разработка технических заданий', 'Сбор требо...
# 1332   Middle (3-6 years)  ['Внутренний аудит информационных систем', 'SW...
# 437   Junior+ (1-3 years)  ['Подготовка презентаций', 'SQL', 'Python', 'А...
#
#               schedule        employment  \
# 1334  Удаленная работа  Полная занятость
# 235        Полный день  Полная занятость
# 1333       Полный день  Полная занятость
# 1332       Полный день  Полная занятость
# 437      Гибкий график  Полная занятость
#
#                                             description  \
# 1334  itvolna.tech — мы быстрорастущая платформа, со...
# 235   чем предстоит заниматься:  коммуницировать с з...
# 1333  mkomov studio — студия решения задач государст...
# 1332  команда единомышленников создающая коробочные ...
# 437   сейчас мы активно ищем аналитиков в команду по...
#
#                                  description_lemmatized  salary_from  \
# 1334  itvolna tech быстрорастущий платформа создават...          NaN
# 235   предстоять заниматься коммуницировать заказчик...          NaN
# 1333  mkomov studio студия решение задача государств...    240000.00
# 1332  команда единомышленник создавать коробочный пр...          NaN
# 437   активно искать аналитик команда разработка нов...          NaN
#
#       salary_to                 salary_bin  \
# 1334  330000.00           Больше 300 тысяч
# 235         NaN              ЗП не указана
# 1333  280000.00  От 200 тысяч до 300 тысяч
# 1332        NaN              ЗП не указана
# 437         NaN              ЗП не указана
#
#                        key_skills_from_key_skills_field  \
# 1334  MS SQL, SQL, UML, BPMN, Системный анализ, инте...
# 235                                                 NaN
# 1333  Системный анализ, BPMN, Разработка технических...
# 1332  Бизнес-анализ, BPMN, SQL, IDEF3, Системный ана...
# 437   SQL, Python, Аналитическое мышление, Подготовк...
#
#      hard_skills_from_description          soft_skills_from_description  \
# 1334                          NaN                          Документация
# 235                           NaN                          Документация
# 1333                          NaN           Документация, Проактивность
# 1332                          NaN  Документация, Аналитическое мышление
# 437                           NaN                                   NaN
#
#      duplicates dataset_type
# 1334                      sa
# 235                       sa
# 1333                      sa
# 1332                      sa
# 437                       sa

# %%
#проверяем суммарную длину датасета перед объединением
len(data_analysts)+len(sistem_analysts)
# Out:
# 3716

# %%
#объединяем датасеты
data = pd.concat([data_analysts, sistem_analysts] )
len(data)
# Out:
# 3716

# %%
brief(data)
# Out:
# Информация по датасету
#
# Первые пять строк датафрейма:
#              id                                               name  \
# 338   101746482                                      Дата аналитик
# 1111   96969442         Аналитик данных в команду Рейнджеры (M+/S)
# 1579   98824646  Аналитик данных в команду Обработки данных (Te...
# 571    94290887          Ведущий аналитик данных (бизнес-аналитик)
# 12    100080002                Продуктовый аналитик / Data Analyst
#
#             published_at                    alternate_url      type  \
# 338  2024-06-11 15:07:30  https://hh.ru/vacancy/101746482  Открытая
# 1111 2024-06-11 14:52:27   https://hh.ru/vacancy/96969442  Открытая
# 1579 2024-06-11 14:47:12   https://hh.ru/vacancy/98824646  Открытая
# 571  2024-06-11 14:36:37   https://hh.ru/vacancy/94290887  Открытая
# 12   2024-06-11 14:34:15  https://hh.ru/vacancy/100080002  Открытая
#
#          employer                         department          area  \
# 338        RUTUBE                                NaN        Москва
# 1111       Контур                                NaN  Екатеринбург
# 1579       Контур                                NaN  Екатеринбург
# 571   Спортмастер  Компания «СПОРТМАСТЕР», Логистика      Балашиха
# 12      Photo Lab                                NaN        Москва
#
#                experience                                         key_skills  \
# 338    Middle (3-6 years)  ['SQL', 'WEB аналитика', 'Clickhouse', 'Яндекс...
# 1111   Middle (3-6 years)  ['Power BI', 'Python', 'SQL', 'Математическое ...
# 1579   Middle (3-6 years)  ['MS SQL', 'Анализ данных', 'Управление команд...
# 571   Junior+ (1-3 years)  ['Анализ данных', 'SQL', 'Power BI', 'Аналитик...
# 12    Junior+ (1-3 years)  ['Linux', 'SQL', 'поведение пользователей', 'D...
#
#               schedule        employment  \
# 338        Полный день  Полная занятость
# 1111  Удаленная работа  Полная занятость
# 1579  Удаленная работа  Полная занятость
# 571        Полный день  Полная занятость
# 12    Удаленная работа  Полная занятость
#
#                                             description  \
# 338   rutube - крупнейший российский видеохостинг, г...
# 1111  контур — экосистема продуктов для бизнеса. мы ...
# 1579  команда состоит из разработчиков баз данных sq...
# 571   отдел отчетности и контроллинга приглашаем ана...
# 12    making mobile photo editing available to anyon...
#
#                                  description_lemmatized  salary_from  \
# 338   rutube крупный российский видеохостинг собират...          NaN
# 1111  контур экосистема продукт бизнес создавать реш...          NaN
# 1579  команда состоять разработчик база данные sql а...          NaN
# 571   отдел отчетность контроллинг приглашать аналит...          NaN
# 12    making mobile photo editing available to anyon...    135000.00
#
#       salary_to                 salary_bin  \
# 338         NaN              ЗП не указана
# 1111        NaN              ЗП не указана
# 1579        NaN              ЗП не указана
# 571         NaN              ЗП не указана
# 12    185000.00  От 100 тысяч до 200 тысяч
#
#                        key_skills_from_key_skills_field  \
# 338   SQL, WEB аналитика, Аналитическое мышление, Ян...
# 1111  SQL, Python, Power BI, Математическое моделиро...
# 1579  Написание документации для пользователей, Разр...
# 571   SQL, Базы данных, Аналитика, Аналитическое мыш...
# 12    SQL, PostgreSQL, Python, MS Excel, LTV, AppsFl...
#
#      hard_skills_from_description soft_skills_from_description duplicates  \
# 338                           NaN                          NaN
# 1111                          NaN                          NaN
# 1579                       Pandas                 Документация
# 571                           NaN                          NaN
# 12                         Pandas                          NaN
#
#      dataset_type
# 338            da
# 1111           da
# 1579           da
# 571            da
# 12             da
# Описательная статистика:
#                 id  salary_from  salary_to
# count      3716.00       704.00     507.00
# mean   98711146.07    132542.98  192250.14
# std     4487851.76     72380.37  106554.77
# min    52410168.00     20000.00   20000.00
# 25%    96159924.00     75000.00  100000.00
# 50%    99193958.50    120000.00  180000.00
# 75%   102375618.25    187000.00  280000.00
# max   103584669.00    398000.00  580000.00
# Общая информация о датафрейме:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3716 entries, 338 to 22
# Data columns (total 22 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   id                                3716 non-null   int64
#  1   name                              3716 non-null   object
#  2   published_at                      3716 non-null   datetime64[ns]
#  3   alternate_url                     3716 non-null   object
#  4   type                              3716 non-null   object
#  5   employer                          3716 non-null   object
#  6   department                        882 non-null    object
#  7   area                              3716 non-null   object
#  8   experience                        3716 non-null   object
#  9   key_skills                        3716 non-null   object
#  10  schedule                          3716 non-null   object
#  11  employment                        3716 non-null   object
#  12  description                       3716 non-null   object
#  13  description_lemmatized            3716 non-null   object
#  14  salary_from                       704 non-null    float64
#  15  salary_to                         507 non-null    float64
#  16  salary_bin                        3716 non-null   object
#  17  key_skills_from_key_skills_field  2367 non-null   object
#  18  hard_skills_from_description      988 non-null    object
#  19  soft_skills_from_description      2015 non-null   object
#  20  duplicates                        3716 non-null   object
#  21  dataset_type                      3716 non-null   object
# dtypes: datetime64[ns](1), float64(2), int64(1), object(18)
# memory usage: 667.7+ KB
#
# Количество явных дубликатов в датафрейме: 0
#
# Процент пропущенных значений в столбцах:
# department: 76.26%
# salary_from: 81.05%
# salary_to: 86.36%
# key_skills_from_key_skills_field: 36.30%
# hard_skills_from_description: 73.41%
# soft_skills_from_description: 45.78%

# %% [markdown]
# Типы данных не изменились, новых явных дубликатов после объединения не появилось. Неявные дубликаты также отсутствуют

# %% [markdown]
# ### Работа с пропусками  <a id="chapter4"></a>

# %% [markdown]
# Начнем с пропусков в колонках с навыками, рассмотрим какие есть скиллы и как часто они встречаются:

# %%
# с помощью функции переведем все значения в нижний регистр, удалим лишние пробелы, если они есть
def columns_low(data, columns):
    for column in columns:
        data[column] = data[column].apply(
            lambda x: x.lower().strip() if isinstance(x, str) and pd.notna(x) 
            else x  # Если значение не строка или NaN, оставляем без изменений
        )
    return data

# %%
list_col= ['soft_skills_from_description', 
           'hard_skills_from_description', 
           'key_skills_from_key_skills_field',
           'name',
           'employer'
          ]
data = columns_low(data, list_col)
data.head()
# Out:
#              id                                               name  \
# 338   101746482                                      дата аналитик
# 1111   96969442         аналитик данных в команду рейнджеры (m+/s)
# 1579   98824646  аналитик данных в команду обработки данных (te...
# 571    94290887          ведущий аналитик данных (бизнес-аналитик)
# 12    100080002                продуктовый аналитик / data analyst
#
#             published_at                    alternate_url      type  \
# 338  2024-06-11 15:07:30  https://hh.ru/vacancy/101746482  Открытая
# 1111 2024-06-11 14:52:27   https://hh.ru/vacancy/96969442  Открытая
# 1579 2024-06-11 14:47:12   https://hh.ru/vacancy/98824646  Открытая
# 571  2024-06-11 14:36:37   https://hh.ru/vacancy/94290887  Открытая
# 12   2024-06-11 14:34:15  https://hh.ru/vacancy/100080002  Открытая
#
#          employer                         department          area  \
# 338        rutube                                NaN        Москва
# 1111       контур                                NaN  Екатеринбург
# 1579       контур                                NaN  Екатеринбург
# 571   спортмастер  Компания «СПОРТМАСТЕР», Логистика      Балашиха
# 12      photo lab                                NaN        Москва
#
#                experience                                         key_skills  \
# 338    Middle (3-6 years)  ['SQL', 'WEB аналитика', 'Clickhouse', 'Яндекс...
# 1111   Middle (3-6 years)  ['Power BI', 'Python', 'SQL', 'Математическое ...
# 1579   Middle (3-6 years)  ['MS SQL', 'Анализ данных', 'Управление команд...
# 571   Junior+ (1-3 years)  ['Анализ данных', 'SQL', 'Power BI', 'Аналитик...
# 12    Junior+ (1-3 years)  ['Linux', 'SQL', 'поведение пользователей', 'D...
#
#               schedule        employment  \
# 338        Полный день  Полная занятость
# 1111  Удаленная работа  Полная занятость
# 1579  Удаленная работа  Полная занятость
# 571        Полный день  Полная занятость
# 12    Удаленная работа  Полная занятость
#
#                                             description  \
# 338   rutube - крупнейший российский видеохостинг, г...
# 1111  контур — экосистема продуктов для бизнеса. мы ...
# 1579  команда состоит из разработчиков баз данных sq...
# 571   отдел отчетности и контроллинга приглашаем ана...
# 12    making mobile photo editing available to anyon...
#
#                                  description_lemmatized  salary_from  \
# 338   rutube крупный российский видеохостинг собират...          NaN
# 1111  контур экосистема продукт бизнес создавать реш...          NaN
# 1579  команда состоять разработчик база данные sql а...          NaN
# 571   отдел отчетность контроллинг приглашать аналит...          NaN
# 12    making mobile photo editing available to anyon...    135000.00
#
#       salary_to                 salary_bin  \
# 338         NaN              ЗП не указана
# 1111        NaN              ЗП не указана
# 1579        NaN              ЗП не указана
# 571         NaN              ЗП не указана
# 12    185000.00  От 100 тысяч до 200 тысяч
#
#                        key_skills_from_key_skills_field  \
# 338   sql, web аналитика, аналитическое мышление, ян...
# 1111  sql, python, power bi, математическое моделиро...
# 1579  написание документации для пользователей, разр...
# 571   sql, базы данных, аналитика, аналитическое мыш...
# 12    sql, postgresql, python, ms excel, ltv, appsfl...
#
#      hard_skills_from_description soft_skills_from_description duplicates  \
# 338                           NaN                          NaN
# 1111                          NaN                          NaN
# 1579                       pandas                 документация
# 571                           NaN                          NaN
# 12                         pandas                          NaN
#
#      dataset_type
# 338            da
# 1111           da
# 1579           da
# 571            da
# 12             da

# %%
data['soft_skills_from_description'].value_counts()
# Out:
# документация                                                                        1168
# коммуникация, документация                                                           213
# коммуникация                                                                         175
# аналитическое мышление                                                               148
# документация, аналитическое мышление                                                  89
# проактивность                                                                         33
# документация, проактивность                                                           29
# документация, переговоры                                                              22
# коммуникация, документация, аналитическое мышление                                    15
# проактивность, аналитическое мышление                                                 15
# коммуникация, проактивность                                                           10
# коммуникация, аналитическое мышление                                                  10
# переговоры                                                                             8
# коммуникация, переговоры                                                               8
# коммуникация, документация, проактивность                                              6
# креативность, аналитическое мышление                                                   6
# коммуникация, документация, переговоры                                                 6
# документация, креативность                                                             5
# креативность                                                                           5
# адаптивность                                                                           4
# принятие решений                                                                       4
# документация, проактивность, переговоры                                                3
# коммуникация, переговоры, аналитическое мышление                                       3
# документация, проактивность, креативность                                              3
# документация, переговоры, аналитическое мышление                                       2
# коммуникация, адаптивность                                                             2
# коммуникация, критическое мышление                                                     2
# коммуникация, решение проблем, презентация результатов, внимание к деталям             2
# тайм-менеджмент                                                                        2
# коммуникация, документация, креативность                                               1
# документация, креативность, аналитическое мышление                                     1
# коммуникация, документация, проактивность, переговоры                                  1
# тайм-менеджмент, документация                                                          1
# коммуникация, письменная коммуникация, документация                                    1
# документация, проактивность, аналитическое мышление                                    1
# решение проблем, принятие решений                                                      1
# тайм-менеджмент, документация, проактивность, переговоры, аналитическое мышление       1
# коммуникация, решение проблем, критическое мышление, внимание к деталям                1
# коммуникация, проактивность, креативность                                              1
# коммуникация, решение проблем                                                          1
# коммуникация, документация, презентация результатов                                    1
# коммуникация, тайм-менеджмент, креативность, аналитическое мышление                    1
# коммуникация, документация, проактивность, аналитическое мышление                      1
# решение проблем                                                                        1
# эмпатия                                                                                1
# документация, эмпатия, аналитическое мышление                                          1
# Name: soft_skills_from_description, dtype: int64

# %% [markdown]
# Список уникальных значений из столбца soft_skills_from_description содержит строки, в которых навыки объединены через запятую. Чтобы работать с каждым навыком отдельно, можно "взорвать" (разделить) эти строки, удалить дубликаты и получить список уникальных навыков из столбца.

# %%
soft_skills = list(
    data['soft_skills_from_description']
    .dropna()  # Удаляем NaN
    .str.split(', ')  # Разделяем строки по запятой и пробелу
    .explode()  # Взрываем списки в отдельные строки
    .str.strip()  # Удаляем лишние пробелы
    .unique()  # Извлекаем уникальные значения
)
soft_skills
# Out:
# ['документация',
#  'аналитическое мышление',
#  'коммуникация',
#  'решение проблем',
#  'принятие решений',
#  'проактивность',
#  'креативность',
#  'адаптивность',
#  'тайм-менеджмент',
#  'переговоры',
#  'эмпатия',
#  'критическое мышление',
#  'внимание к деталям',
#  'презентация результатов',
#  'письменная коммуникация']

# %% [markdown]
# Поступим также с хард скилами и с ключевыми навыками, для чего напишем функцию:

# %%
def get_uniq_vals(data, column):
 
    uniq_vals = sorted(
                data[column]
                .dropna()  # Удаляем NaN
                .str.split(',')  # Разделяем строки по запятой и пробелу
                .explode()  # Взрываем списки в отдельные строки
                .str.strip()  # Удаляем лишние пробелы
                .unique()  # Извлекаем уникальные значения
                .tolist()  # Преобразуем в список
            )
        
    return uniq_vals

#сразу проверяем функцию
hard_skills = get_uniq_vals(data, 'hard_skills_from_description')
hard_skills
# Out:
# ['confluence',
#  'google sheets',
#  'pandas',
#  'математическая статистика',
#  'юнит-экономика']

# %%
key_skills_list = get_uniq_vals(data, 'key_skills_from_key_skills_field')
key_skills_list
# Out:
# ['.net',
#  '.net core',
#  '.net framework',
#  '199-и',
#  '1c',
#  '1c ка',
#  '1c кадры и бухгалтерия',
#  '1c ух',
#  '1c: erp',
#  '1c: предприятие',
#  '1с',
#  '1с 8.0',
#  '1с 8.3',
#  '1с erp',
#  '1с erp битфинанс',
#  '1с erp)',
#  '1с бп',
#  '1с программирование',
#  '1с ут 11',
#  '1с ут11',
#  '1с-битрикс',
#  '1с:',
#  '1с: erp',
#  '1с: erp управление предприятием',
#  '1с: бит финанс',
#  '1с: бухгалтерия',
#  '1с: бухгалтерия и склад',
#  '1с: документооборот',
#  '1с: зарплата и кадры',
#  '1с: зарплата и управление персоналом',
#  '1с: комплексная автоматизация',
#  '1с: логистика',
#  '1с: предприятие',
#  '1с: предприятие 8',
#  '1с: предприятие: розница',
#  '1с: предприятие: управление строительной организацией',
#  '1с: розница',
#  '1с: торговля',
#  '1с: торговля и склад',
#  '1с: управление предприятием',
#  '1с: управление производственным предприятием',
#  '1с: управление торговлей',
#  '1с: управление холдингом',
#  '1с: фгис меркурий',
#  '1с:erp',
#  '1с:тоир',
#  '223-фз',
#  '3624-у',
#  '3gpp',
#  '44-фз',
#  '483-п',
#  '646-п',
#  'a/b тестирование',
#  'a/b тесты',
#  'a/b/n',
#  'ab тестирование',
#  'ab-test',
#  'abc-анализ',
#  'access',
#  'acid',
#  'ad hoc analysis',
#  'ad-hoc',
#  'adodb',
#  'agile',
#  'agile project management',
#  'ai',
#  'aiohttp',
#  'airflow',
#  'alation',
#  'alm',
#  'alteryx',
#  'altova xml spy',
#  'aml',
#  'amocrm',
#  'amplitude',
#  'anaconda',
#  'anaconda3',
#  'analysis',
#  'analyst',
#  'analytic bi',
#  'analytical skills',
#  'anaplan',
#  'android',
#  'anti-fraud',
#  'apache',
#  'apache airflow',
#  'apache kafka',
#  'apache nifi',
#  'apache spark',
#  'apache superset',
#  'api',
#  'api документация',
#  'apple search ads',
#  'appmetrica',
#  'appmetrika',
#  'appsflyer',
#  'arcgis',
#  'arcgis qgis git/gitlab python пространственные базы данных agile',
#  'archimate',
#  'architecture analyst',
#  'arduino',
#  'arenadata',
#  'arenadatadb (greenplum)',
#  'arendata',
#  'aris',
#  'artemismq',
#  'artificial intelligence',
#  'asciidoc',
#  'aso-кубы',
#  'asp.net',
#  'astra linux',
#  'async api',
#  'atlassian confluence',
#  'atlassian jira',
#  'autocad',
#  'aws',
#  'aws redshift',
#  'axapta',
#  'b2b исследования',
#  'b2b продажи',
#  'b2c',
#  'babok',
#  'backend',
#  'backend -php',
#  'balsamiq',
#  'base station subsystem',
#  'bash',
#  'bert',
#  'beta-тестирования',
#  'bff',
#  'bi',
#  'bi apache superset',
#  'bi аналитик',
#  'bi аналитика',
#  'bi инструменты',
#  'bi-инструменты',
#  'bi-отчетность',
#  'bi-система',
#  'bi: visiology/microsoft powerbi',
#  'big data',
#  'bigdata',
#  'bigquery',
#  'bim',
#  'bitrirx24',
#  'bitrix crm',
#  'bitrix24',
#  'black box testing',
#  'blueprint',
#  'bokeh',
#  'bpm',
#  'bpm online',
#  'bpml',
#  'bpmn',
#  'bpmn 2.0',
#  'bpmnsoft',
#  'bpmsoft',
#  'bpwin',
#  'brd',
#  'bss',
#  'bulk-запросы',
#  'business analysis',
#  'business development',
#  'business glossary',
#  'business intelligence systems',
#  'bussinessobject',
#  'c#',
#  'c++',
#  'c4',
#  'c4 diagram',
#  'ca',
#  'calypso',
#  'camunda',
#  'cassandra',
#  'cdm',
#  'celery',
#  'charles proxy',
#  'ci/cd',
#  'ci\\cd',
#  'cjm',
#  'clickhouse',
#  'clickup',
#  'compass+',
#  'computer vision',
#  'comunda',
#  'confluence',
#  'confluence (желательно)',
#  'creatio',
#  'crm',
#  'crm bitrix24',
#  'crm dynamics',
#  'crypto',
#  'css',
#  'css3',
#  'csv',
#  'cистемная аналитика',
#  'cистемы управления базами данных',
#  'daily standup',
#  'dao',
#  'dashboard',
#  'dask',
#  'data',
#  'data analysis',
#  'data analyst',
#  'data base',
#  'data catalog',
#  'data engineer',
#  'data flow',
#  'data governance',
#  'data lake',
#  'data lens',
#  'data management',
#  'data mining',
#  'data science',
#  'data scientist',
#  'data vault',
#  'data warehouse',
#  'data warehousing',
#  'datalens',
#  'datalense',
#  'datamine',
#  'datavault',
#  'dax',
#  'db2',
#  'dbeaver',
#  'dbt',
#  'ddl',
#  'ddos',
#  'dds',
#  'debezium',
#  'deep learning',
#  'demo',
#  'devexpress xpo',
#  'devops',
#  'devtools',
#  'dfd',
#  'dft',
#  'dhcp',
#  'diasoft',
#  'django framework',
#  'dlp',
#  'dmbok dama',
#  'dns',
#  'docker',
#  'docker compose',
#  'doker',
#  'draw.io',
#  'drtm',
#  'dwh',
#  'dwh lead',
#  'dynamics 365',
#  'e-commerce',
#  'e-staff',
#  'eda',
#  'egar e4',
#  'elastic',
#  'elasticsearch',
#  'elk',
#  'elma',
#  'elma 3',
#  'elt',
#  'enterprise architect',
#  'epc',
#  'epс',
#  'er',
#  'er-диаграммы',
#  'erd',
#  'erp',
#  'erp systems',
#  'erp-системы на базе 1с',
#  'erwin',
#  'er‑диаграммы',
#  'esb',
#  'etl',
#  'etl framework',
#  'etl: informatica',
#  'evam',
#  'eviews',
#  'exasol',
#  'excel',
#  'facebook',
#  'fastapi',
#  'fat',
#  'figma',
#  'figmа',
#  'finebi',
#  'fintech',
#  'firebase',
#  'fix',
#  'fixml',
#  'flask',
#  'foodtech',
#  'fork',
#  'fsd',
#  'functional list/matrix',
#  'ga4',
#  'gexcel',
#  'gis',
#  'git',
#  'gitlab',
#  'go',
#  'google adwords',
#  'google analytics',
#  'google big query',
#  'google cloud platform',
#  'google data studio',
#  'google docs',
#  'google sheets',
#  'google tag manager',
#  'google таблицы',
#  'gpt',
#  'grafana',
#  'graphana',
#  'graphql',
#  'graphviz',
#  'greenplam',
#  'greenplum',
#  'greenplumdb',
#  'grp',
#  'grpc',
#  'gsm',
#  'gtm',
#  'hadoop',
#  'hcm',
#  'hive',
#  'hr',
#  'hr-tech',
#  'hr-аналитика',
#  'hrm',
#  'html',
#  'html5',
#  'http',
#  'http запросы',
#  'https',
#  'hyper-v',
#  'hypersonic sql',
#  'ibm cognos',
#  'ibm ilog cplex',
#  'ibm unica',
#  'icaap',
#  'ide',
#  'idef',
#  'idef0',
#  'idef3',
#  'idm',
#  'iiko',
#  'improvado',
#  'informatica',
#  'information security',
#  'insomnia',
#  'internet',
#  'internet marketing',
#  'ios',
#  'iot',
#  'ip телефония',
#  'ipc',
#  'irb',
#  'iso',
#  'it',
#  'itil',
#  'itsm',
#  'java',
#  'javascript',
#  'jenkins',
#  'jetstat',
#  'jira',
#  'jira (желательно)',
#  'join',
#  'join)',
#  'jquery',
#  'js',
#  'json',
#  'json 6',
#  'json api',
#  'json)',
#  'json/xml/xslt',
#  'jsonata',
#  'jtbd',
#  'junior',
#  'jupiter',
#  'jupyter hab',
#  'jupyter notebook',
#  'kafka',
#  'kafka)',
#  'kanban',
#  'keras',
#  'kerberos',
#  'kibana',
#  'knime',
#  'kotlin',
#  'kubernetes',
#  'kvm',
#  'lan',
#  'laravel',
#  'ldap',
#  'leadership skills',
#  'linux',
#  'linux kvm',
#  'llm',
#  'loginom',
#  'looker studio',
#  'low-code',
#  'lowcode',
#  'lr',
#  'lte',
#  'ltv',
#  'lucidchart',
#  'luxms',
#  'machine learning',
#  'macos',
#  'maplnfo professional',
#  'markdown',
#  'mashine learning',
#  'mathematical statistics',
#  'matolib',
#  'matomo',
#  'matplotlib',
#  'mdm',
#  'memcashed',
#  'mes',
#  'meta данные',
#  'metabase',
#  'metrics',
#  'micromine',
#  'microservices',
#  'microsoft access',
#  'microsoft office',
#  'microsoft power bi',
#  'mineframe',
#  'miner',
#  'miro',
#  'miro/draw.io',
#  'mixpanel',
#  'ml',
#  'ml модели',
#  'ml-моделирование',
#  'ml-прогнозирование',
#  'mobile',
#  'mockup',
#  'mongodb',
#  'mq',
#  'mqtt',
#  'ms access',
#  'ms dynamics ax',
#  'ms dynamics crm',
#  'ms excel',
#  'ms excel (vba',
#  'ms exchange server',
#  'ms navision',
#  'ms office',
#  'ms olap',
#  'ms outlook',
#  'ms power bi',
#  'ms powerpoint',
#  'ms project',
#  'ms sql',
#  'ms sql server',
#  'ms visio',
#  'ms visual basic',
#  'ms visual studio',
#  'msa',
#  'msf',
#  'mssql',
#  'murex',
#  'mysql',
#  'navision business central',
#  'nginx',
#  'nifi',
#  'nlp',
#  'nltk',
#  'node-red',
#  'node.js',
#  'nosql',
#  'nosql субд',
#  'notion',
#  'nsm',
#  'numpy',
#  'nuxt',
#  'ods',
#  'olap',
#  'olap (online analytical processing)',
#  'olap инструменты',
#  'olap-кубы',
#  'omnigraffle',
#  'oozie',
#  'opc',
#  'open source',
#  'openai',
#  'openapi',
#  'opencv',
#  'openmetadata',
#  'openproject',
#  'openshift',
#  'openvpn',
#  'openway way4',
#  'optimacros',
#  'oracle',
#  'oracle application express (apex)',
#  'oracle bi',
#  'oracle db',
#  'oracle exadata',
#  'oracle hyperion',
#  'oracle pl/sql',
#  'oracle primavera',
#  'oracle siebel crm',
#  'orm',
#  'panda',
#  'pandas',
#  'php',
#  'php5',
#  'phyton',
#  'pim',
#  'pl/pgsql',
#  'pl/sql',
#  'planning',
#  'plantuml',
#  'plotly',
#  'pmbok',
#  'polars',
#  'posgresql',
#  'postgesql',
#  'postgres',
#  'postgresq',
#  'postgresql',
#  'postman',
#  'postman / swagger',
#  'power bi',
#  'power pivot',
#  'power point',
#  'power query',
#  'power query)',
#  'powerbi',
#  'powerbl',
#  'powerdesigner',
#  'powerquery',
#  'powershell',
#  'pr',
#  'product analytics',
#  'product management',
#  'programmatic',
#  'project management',
#  'prometheus',
#  'pyspark',
#  'python',
#  'python3',
#  'pytorch',
#  'qgis',
#  'qlicksense',
#  'qlickview',
#  'qlik',
#  'qlik sense',
#  'qlikview',
#  'quick sense',
#  'r',
#  'r-keeper',
#  'rabbit mq',
#  'rabbit.mq',
#  'rabbitmq',
#  'raroc',
#  'raspberry pi',
#  'rational unified process',
#  'react',
#  'react.js',
#  'ready to eat',
#  'realtime marketing',
#  'rebbit',
#  'recsys',
#  'redash',
#  'redis',
#  'redmine',
#  'requests',
#  'rest',
#  'rest api',
#  'rest ip',
#  'rest-api',
#  'rest/soap',
#  'rest/web сервисы',
#  'restapi',
#  'restful api',
#  'retail',
#  'retrospective',
#  'rhel',
#  'rice',
#  'risk weighted assets',
#  'river logic',
#  'roas',
#  'roe',
#  'roi',
#  'rorac',
#  'rorwa',
#  'rtb',
#  'rtdm',
#  'rte',
#  'rtm',
#  'runtime crm',
#  'rwa',
#  's2t',
#  'saas',
#  'safe',
#  'salesforce',
#  'samba',
#  'sap',
#  'sap apo',
#  'sap crm',
#  'sap ibp',
#  'sap mm',
#  'sap sm',
#  'saphr',
#  'sas',
#  'sas guide',
#  'sas rtdm',
#  'scada',
#  'scala',
#  'scikit-learn',
#  'scipy',
#  'scm',
#  'scrum',
#  'seaborn',
#  'security grc',
#  'selenium ide',
#  'sequence',
#  'sequence diagram',
#  'serm',
#  'shap/lime',
#  'sharepoint',
#  'shell scripting',
#  'siddhi',
#  'siem',
#  'sklearn',
#  'sles',
#  'smm',
#  'soa',
#  'soap',
#  'soap api',
#  'soap ui',
#  'soapui',
#  'soc',
#  'solar',
#  'son/json-sсhema',
#  'spark',
#  'sparql',
#  'specifications',
#  'spss',
#  'sql',
#  'sql (select',
#  'sql (простые запросы)',
#  'sql запросы',
#  'sql-запросы',
#  'sql.',
#  'sqlite',
#  'ssh',
#  'ssis',
#  'stock market',
#  'stoplight',
#  'streamlit',
#  'superset',
#  'supply chain management',
#  'surpac',
#  'svn',
#  'swagger',
#  'swagger/yaml',
#  'swift',
#  'swot анализ',
#  'swot-анализ',
#  'system analysis',
#  'system analyst',
#  't-sql',
#  'tableau',
#  'task mining',
#  'tcp/ip',
#  'tcp\\ip',
#  'team management',
#  'teamcenter',
#  'tensorflow',
#  'teradata',
#  'teradata studio',
#  'terrasoft crm',
#  'test cases',
#  'tilda',
#  'tms systems',
#  'togaf',
#  'toplog',
#  'transact-sql',
#  'transformers',
#  'trello',
#  'typescript',
#  'uat',
#  'ubuntu server',
#  'uc',
#  'ug',
#  'ui',
#  'ui/ux',
#  'ui/ux проектирование',
#  'uml',
#  'uml 2',
#  'uml-диаграммы',
#  'us',
#  'usability',
#  'use case',
#  'use case analysis',
#  'use cases',
#  'usecase',
#  'user case',
#  'user flow',
#  'user interface',
#  'user stories',
#  'user story',
#  'user story mapping',
#  'userstory',
#  'ux',
#  'ux flow',
#  'ux модели',
#  'ux-схемы',
#  'v-model',
#  'vba',
#  'vertica',
#  'visio',
#  'visiology',
#  'vmware esxi',
#  'voip',
#  'vue',
#  'warehouse management',
#  'waterfall',
#  'wcf',
#  'web',
#  'web api',
#  'web application development',
#  'web аналитика',
#  'web приложения',
#  'web-проект',
#  'wiki',
#  'wildberries',
#  'windows server',
#  'wms',
#  'woe',
#  'ws api',
#  'wsdl',
#  'wsdl/xsd/xml',
#  'wso2 stream processor',
#  'xdr',
#  'xgboost',
#  'xml',
#  'xml/json',
#  'xml/xsd',
#  'xml/xslt',
#  'xpath',
#  'xsd',
#  'xsd-схемы',
#  'xsd/xslt',
#  'xslt',
#  'yaml',
#  'yandex cloud',
#  'yandex data lens',
#  'yandex datalens',
#  'yii2',
#  'youtrack',
#  'а/бх тесты',
#  'а/в-тестирования',
#  'абс',
#  'абс цфт',
#  'аванкор пиф',
#  'автоматизация',
#  'автоматизация etl',
#  'автоматизация бизнес-процессов',
#  'автоматизация и оптимизация процессов',
#  'автоматизация медицинских процессов',
#  'автоматизация процессов',
#  'автоматизация процессов тмц',
#  'автоматизация процессов управления персоналом',
#  'автоматизация управленческой отчетности',
#  'автоматизированное тестирование',
#  'агрегатные функции',
#  'администрирование',
#  'администрирование базы данных',
#  'администрирование ос windows',
#  'администрирование серверов',
#  'аиискуэ',
#  'активные продажи',
#  'активы',
#  'актуарные расчеты',
#  'алгоритмы',
#  'альт сервер',
#  'амбициозность',
#  'амплитуда',
#  'анализ',
#  'анализ абс',
#  'анализ ассортиментной линейки',
#  'анализ бизнес показателей',
#  'анализ бизнес-процессов',
#  'анализ временных рядов',
#  'анализ данных',
#  'анализ документации',
#  'анализ доходности',
#  'анализ и документирование информации',
#  'анализ и моделирование бизнес-процессов',
#  'анализ и формализация требований заказчика',
#  'анализ интеграций',
#  'анализ конкурентной среды',
#  'анализ потребления капитала',
#  'анализ продаж',
#  'анализ продукта',
#  'анализ рисков',
#  'анализ рынка',
#  'анализ текущих финансовых показателей',
#  'анализ требований',
#  'анализ финансовых показателей',
#  'анализ ценообразования',
#  'аналитик',
#  'аналитик bi',
#  'аналитик bpmsoft',
#  'аналитик creatio',
#  'аналитик данных',
#  'аналитика',
#  'аналитика больших массивов данных',
#  'аналитика данных',
#  'аналитика закупок',
#  'аналитика по клиентам',
#  'аналитика продаж',
#  'аналитика требований',
#  'аналитические исследования',
#  'аналитические навыки',
#  'аналитические способности',
#  'аналитический склад ума',
#  'аналитическое мышление',
#  'анаплан',
#  'английский язык',
#  'английский язык (upper-intermediate)',
#  'английский – а2',
#  'английский — a1 — начальный',
#  'английский — b1 — средний',
#  'андеррайтинг',
#  'анти фрод',
#  'антифрод',
#  'артефакты',
#  'архитектура',
#  'архитектурные схемы',
#  'аскуэ',
#  'ассортиментная матрица',
#  'асу',
#  'асу тп',
#  'аудит',
#  'аудит бизнес-процессов',
#  'аудиторские проверки',
#  'база данных',
#  'база данных: olap',
#  'база данных: oracle',
#  'базель',
#  'базельские стандарты',
#  'базовые знания sql',
#  'базы данных',
#  'банк',
#  'банковские гарантии',
#  'банковские операции',
#  'банковские продукты',
#  'банковское дело',
#  'бизнес анализ',
#  'бизнес тестирование',
#  'бизнес-анализ',
#  'бизнес-аналитика',
#  'бизнес-консультирование',
#  'бизнес-модели',
#  'бизнес-моделирование',
#  'бизнес-планирование',
#  'бизнес-процессы',
#  'бизнес-требования',
#  'биржевые торги',
#  'бит.финанс',
#  'битрикс 24',
#  'битрикс24',
#  'бп 3',
#  'брокер',
#  'брокер сообщений',
#  'брокеры сообщений',
#  'брокеры сообщений (rabbit',
#  'бу',
#  'бухгалтерская отчетность',
#  'бухгалтерский учет',
#  'бюджет',
#  'бюджетирование',
#  'валютный рынок',
#  'веб-аналитика',
#  'веб-программирование',
#  'веб-технологии',
#  'ведение документации',
#  'ведение задачи от сбора требований',
#  'ведение клиентской базы',
#  'ведение отчетности',
#  'ведение переговоров',
#  'ведение переписки',
#  'ведение проектной доументации',
#  'ведении беклога',
#  'взаимодействие с заказчиком',
#  'взаимодействие с разработчиками 1с',
#  'взвешенные по риску активы',
#  'взвешенные с учетом риска',
#  'визуализация',
#  'визуализация данных',
#  'витрины',
#  'витрины данных',
#  'владение прикладными решениями 1с: (1с бп',
#  'внедрение информационных систем',
#  'внедрение систем информационной безопасности',
#  'внимание к деталям',
#  'внимательность',
#  'внимательность к деталям',
#  'внутренний аудит',
#  'внутренний аудит информационных систем',
#  'внутренний контроль',
#  'внутренний финансовый аудит',
#  'вподк',
#  'впр',
#  'выборка',
#  'высокая скорость печати',
#  'высокий уровень самоорганизации',
#  'выстраивание метрик',
#  'высшее образование',
#  'высшее образование (экономическое или системный анализ)',
#  'генерация идей',
#  'геоинформационные системы',
#  'геология',
#  'геотехнология',
#  'гибкость мышления',
#  'гигиена клиентской базы',
#  'гис',
#  'гост',
#  'гост 19',
#  'гост 34',
#  'гост 56939',
#  'госты',
#  'государственные закупки',
#  'готовая еда',
#  'готовность обучаться',
#  'грамотная речь',
#  'грамотная речь и письмо',
#  'грамотность',
#  'данных',
#  'дашборд',
#  'дашборды',
#  'девелопмент',
#  'декомпозирование и приоритизирование больших комплексных задач',
#  'деловая коммуникация',
#  'деловая переписка',
#  'деловое общение',
#  'депозиты',
#  'диасофт',
#  'диасофт 5nt',
#  'динамическое ценообразование',
#  'дистанционное зондирование',
#  'до выкладки в прод',
#  'доброжелательность',
#  'добросовестность',
#  'документирование',
#  'документирование бизнес-требований',
#  'достаточность капитала банка',
#  'дружелюбие',
#  'ехсеl',
#  'желание зарабатывать',
#  'желание обучаться',
#  'желание постоянно развиваться',
#  'желание работать и развиваться',
#  'желание развиваться',
#  'жизненный цикл по',
#  'жкх',
#  'заведения данных в 1с',
#  'заключение договоров',
#  'закупки',
#  'зенит-р.пиф',
#  'знание 1с',
#  'знание excel',
#  'знание ms office',
#  'знание бд',
#  'знание информационной системы 1с унф',
#  'знание микросервисной архитектуры',
#  'знание офисных программ',
#  'знание устройства автомобиля',
#  'извлечение данных',
#  'инвестиции',
#  'инвестиционная деятельность',
#  'инвестиционные риски',
#  'индустрия 4.0',
#  'инициативность в решении задач',
#  'инициативность и лидерство',
#  'инструменты bi',
#  'интеграции',
#  'интеграционное тестирование',
#  'интеграция',
#  'интеграция 1с',
#  'интеграция с внешними системами',
#  'интеграция учетных систем 1с',
#  'интеллектуальные счётчики',
#  'интеллектуальный анализ данных',
#  'интернет банк',
#  'интерпретация данных',
#  'информационная безопасность',
#  'информационные технологии',
#  'искусственный интеллект',
#  'исполнение поручений руководителя',
#  'использование и описывание openapi спецификации (swagger)',
#  'исследования рынка',
#  'исследовательский анализ данных',
#  'исходящие звонки',
#  ...]

# %%
ks = key_skills_list
ks = pd.DataFrame(ks)
ks.to_excel('key_skills.xlsx', index=False)

# %%
skills_data = pd.read_excel("C:/Users/Guseva/Downloads/key_skills.xlsx")
skills_data.head()
# Out:
#             skill skill_type
# 0            .net       hard
# 1       .net core       hard
# 2  .net framework       hard
# 3           199-и       hard
# 4              1c       hard

# %%
# разделение навыков на hard и soft
hard_skills = set(skills_data[skills_data['skill_type'] == 'hard']['skill'])
soft_skills = set(skills_data[skills_data['skill_type'] == 'soft']['skill'])

def update_skills(row):
    # существующие значения в колонках описания
    existing_hard = set(str(row['hard_skills_from_description']).split(', ')) if pd.notna(row['hard_skills_from_description']) else set()
    existing_soft = set(str(row['soft_skills_from_description']).split(', ')) if pd.notna(row['soft_skills_from_description']) else set()

    # навыки из столбца key_skills_from_key_skills_field
    skills = set(str(row['key_skills_from_key_skills_field']).split(', '))

    # определение hard и soft навыков
    hard_to_add = skills & hard_skills
    soft_to_add = skills & soft_skills

    # обновление колонок
    if hard_to_add or existing_hard:
        row['hard_skills_from_description'] = ', '.join(sorted(existing_hard | hard_to_add))
    else:
        row['hard_skills_from_description'] = pd.NA

    if soft_to_add or existing_soft:
        row['soft_skills_from_description'] = ', '.join(sorted(existing_soft | soft_to_add))
    else:
        row['soft_skills_from_description'] = pd.NA

    return row

# применение функции для обновления датасета
data = data.apply(update_skills, axis=1)

# %%
data.head()
# Out:
#              id                                               name  \
# 338   101746482                                      дата аналитик
# 1111   96969442         аналитик данных в команду рейнджеры (m+/s)
# 1579   98824646  аналитик данных в команду обработки данных (te...
# 571    94290887          ведущий аналитик данных (бизнес-аналитик)
# 12    100080002                продуктовый аналитик / data analyst
#
#             published_at                    alternate_url      type  \
# 338  2024-06-11 15:07:30  https://hh.ru/vacancy/101746482  Открытая
# 1111 2024-06-11 14:52:27   https://hh.ru/vacancy/96969442  Открытая
# 1579 2024-06-11 14:47:12   https://hh.ru/vacancy/98824646  Открытая
# 571  2024-06-11 14:36:37   https://hh.ru/vacancy/94290887  Открытая
# 12   2024-06-11 14:34:15  https://hh.ru/vacancy/100080002  Открытая
#
#          employer                         department          area  \
# 338        rutube                                NaN        Москва
# 1111       контур                                NaN  Екатеринбург
# 1579       контур                                NaN  Екатеринбург
# 571   спортмастер  Компания «СПОРТМАСТЕР», Логистика      Балашиха
# 12      photo lab                                NaN        Москва
#
#                experience                                         key_skills  \
# 338    Middle (3-6 years)  ['SQL', 'WEB аналитика', 'Clickhouse', 'Яндекс...
# 1111   Middle (3-6 years)  ['Power BI', 'Python', 'SQL', 'Математическое ...
# 1579   Middle (3-6 years)  ['MS SQL', 'Анализ данных', 'Управление команд...
# 571   Junior+ (1-3 years)  ['Анализ данных', 'SQL', 'Power BI', 'Аналитик...
# 12    Junior+ (1-3 years)  ['Linux', 'SQL', 'поведение пользователей', 'D...
#
#               schedule        employment  \
# 338        Полный день  Полная занятость
# 1111  Удаленная работа  Полная занятость
# 1579  Удаленная работа  Полная занятость
# 571        Полный день  Полная занятость
# 12    Удаленная работа  Полная занятость
#
#                                             description  \
# 338   rutube - крупнейший российский видеохостинг, г...
# 1111  контур — экосистема продуктов для бизнеса. мы ...
# 1579  команда состоит из разработчиков баз данных sq...
# 571   отдел отчетности и контроллинга приглашаем ана...
# 12    making mobile photo editing available to anyon...
#
#                                  description_lemmatized  salary_from  \
# 338   rutube крупный российский видеохостинг собират...          NaN
# 1111  контур экосистема продукт бизнес создавать реш...          NaN
# 1579  команда состоять разработчик база данные sql а...          NaN
# 571   отдел отчетность контроллинг приглашать аналит...          NaN
# 12    making mobile photo editing available to anyon...    135000.00
#
#       salary_to                 salary_bin  \
# 338         NaN              ЗП не указана
# 1111        NaN              ЗП не указана
# 1579        NaN              ЗП не указана
# 571         NaN              ЗП не указана
# 12    185000.00  От 100 тысяч до 200 тысяч
#
#                        key_skills_from_key_skills_field  \
# 338   sql, web аналитика, аналитическое мышление, ян...
# 1111  sql, python, power bi, математическое моделиро...
# 1579  написание документации для пользователей, разр...
# 571   sql, базы данных, аналитика, аналитическое мыш...
# 12    sql, postgresql, python, ms excel, ltv, appsfl...
#
#                            hard_skills_from_description  \
# 338      clickhouse, sql, web аналитика, яндекс.метрика
# 1111  power bi, python, sql, математическое моделиро...
# 1579  ms sql, pandas, python, анализ данных, написан...
# 571   power bi, sql, tableau, анализ данных, аналити...
# 12    airflow, apple search ads, appsflyer, b2c, das...
#
#                            soft_skills_from_description duplicates  \
# 338                              аналитическое мышление
# 1111                                               <NA>
# 1579  аналитическое мышление, документация, управлен...
# 571                              аналитическое мышление
# 12                                                 <NA>
#
#      dataset_type
# 338            da
# 1111           da
# 1579           da
# 571            da
# 12             da

# %%
def losses(df): 
    for column in df.columns:
        missing_percentage = df[column].isna().mean() * 100
        if missing_percentage > 0:
            print(f"{column}: {missing_percentage:.2f}%")

# %%
losses(data)
# Out:
# department: 76.26%
# salary_from: 81.05%
# salary_to: 86.36%
# key_skills_from_key_skills_field: 36.30%
# hard_skills_from_description: 26.88%
# soft_skills_from_description: 38.75%

# %%
data[['hard_skills_from_description', 
      'soft_skills_from_description'
     ]]= data[[
    'hard_skills_from_description', 
    'soft_skills_from_description'
     ]].fillna('информация неизвестна')

# %%
data['hard_skills_from_description'].value_counts().head()
# Out:
# информация неизвестна                    999
# confluence                               231
# pandas                                   103
# python, sql                               37
# bpmn, kafka, rabbitmq, rest, sql, uml     16
# Name: hard_skills_from_description, dtype: int64

# %%
data['soft_skills_from_description'].value_counts().head()
# Out:
# информация неизвестна                   1440
# документация                            1014
# аналитическое мышление                   239
# документация, коммуникация               175
# аналитическое мышление, документация     146
# Name: soft_skills_from_description, dtype: int64

# %%
# получим топ-5 наборов навыков для дата-аналитиков
da_hard_top = data.query('dataset_type == "da"')['hard_skills_from_description'].value_counts().head()
da_soft_top = data.query('dataset_type == "da"')['soft_skills_from_description'].value_counts().head()

# получим топ-5 наборов навыков для системных аналитиков
sa_hard_top = data.query('dataset_type == "sa"')['hard_skills_from_description'].value_counts().head()
sa_soft_top = data.query('dataset_type == "sa"')['soft_skills_from_description'].value_counts().head()

print("Топ 5 наборов навыков для дата-аналитиков:")
print("-" * 40)
print("Хард скиллы:")
print(da_hard_top)
print("\nСофт скиллы:")
print(da_soft_top)

print("\nТоп 5 наборов навыков для системных аналитиков:")
print("-" * 40)
print("Хард скиллы:")
print(sa_hard_top)
print("\nСофт скиллы:")
print(sa_soft_top)
# Out:
# Топ 5 наборов навыков для дата-аналитиков:
# ----------------------------------------
# Хард скиллы:
# информация неизвестна    561
# pandas                   102
# python, sql               37
# confluence                30
# sql                       13
# Name: hard_skills_from_description, dtype: int64
#
# Софт скиллы:
# информация неизвестна                   1020
# аналитическое мышление                   183
# документация                             181
# коммуникация                              84
# аналитическое мышление, документация      27
# Name: soft_skills_from_description, dtype: int64
#
# Топ 5 наборов навыков для системных аналитиков:
# ----------------------------------------
# Хард скиллы:
# информация неизвестна                                                                                                                                                                                                                                                                                                                                                                                 438
# confluence                                                                                                                                                                                                                                                                                                                                                                                            201
# bpmn, kafka, rabbitmq, rest, sql, uml                                                                                                                                                                                                                                                                                                                                                                  16
# apache kafka, bpmn, ms sql, scrum, sql, uml                                                                                                                                                                                                                                                                                                                                                            10
# agile, bpmn, business analysis, data base, http, json api, python, rest, retail, scrum, sql, system analysis, uml, use case analysis, waterfall, анализ бизнес показателей, анализ данных, анализ требований, базы данных, бизнес-анализ, веб-программирование, жизненный цикл по, оптимизация бизнес-процессов, работа с базами данных, разработка по, системный анализ, техническая документация      9
# Name: hard_skills_from_description, dtype: int64
#
# Софт скиллы:
# документация                            833
# информация неизвестна                   420
# документация, коммуникация              149
# аналитическое мышление, документация    119
# коммуникация                             60
# Name: soft_skills_from_description, dtype: int64

# %% [markdown]
# Теперь займемся пропусками в зарплатах. Обратимся к столбцу salary_bin

# %%
data['salary_bin'].value_counts()
# Out:
# ЗП не указана                3209
# От 100 тысяч до 200 тысяч     171
# От 200 тысяч до 300 тысяч     117
# Больше 300 тысяч              110
# Меньше 100 тысяч              109
# Name: salary_bin, dtype: int64

# %% [markdown]
# Данных с неуказанными зарплатами существенно больше.

# %%
data.query('salary_bin == "ЗП не указана"')[['salary_from', 'salary_to']].head(10)
# Out:
#       salary_from  salary_to
# 338           NaN        NaN
# 1111          NaN        NaN
# 1579          NaN        NaN
# 571           NaN        NaN
# 246     150000.00        NaN
# 11      350000.00        NaN
# 23            NaN        NaN
# 1736          NaN        NaN
# 146           NaN        NaN
# 1632    100000.00        NaN

# %%
data.query('salary_bin == "ЗП не указана"')['salary_to'].unique()
# Out:
# array([nan])

# %%
data.query('salary_bin == "ЗП не указана"')['salary_from'].unique()
# Out:
# array([    nan, 150000., 350000., 100000.,  50000., 257125.,  40000.,
#         63000.,  72000.,  80000., 300000.,  65000.,  90000., 112200.,
#         55000.,  74450., 180000.,  60000.,  51000., 200000.,  85000.,
#        130000.,  45000.,  76000.,  70000.,  42500., 250000., 120000.,
#         30000., 115000.,  95000.,  78000.,  76700.,  75000., 140000.,
#         61000., 123000., 110000., 137000., 210000.,  35000., 160000.,
#         40050., 190000.,  84000.,  57000., 220000.,  46000., 270000.,
#        230000., 233000., 233750., 172413., 290000., 261800.,  50200.,
#        152000., 105000., 195000., 245000., 170000.,  50600.,  59000.])

# %%
data.query('salary_bin != "ЗП не указана"')[['salary_bin','salary_from', 'salary_to']].head(20)
# Out:
#                      salary_bin  salary_from  salary_to
# 12    От 100 тысяч до 200 тысяч    135000.00  185000.00
# 1737  От 100 тысяч до 200 тысяч    100000.00  120000.00
# 337            Меньше 100 тысяч     45000.00   50000.00
# 1730  От 100 тысяч до 200 тысяч          NaN  150000.00
# 238            Больше 300 тысяч    299200.00  495550.00
# 1554  От 100 тысяч до 200 тысяч          NaN  170000.00
# 1553  От 100 тысяч до 200 тысяч          NaN  170000.00
# 328   От 100 тысяч до 200 тысяч          NaN  142000.00
# 1713           Меньше 100 тысяч          NaN   90000.00
# 293            Меньше 100 тысяч          NaN   25000.00
# 971   От 200 тысяч до 300 тысяч          NaN  280000.00
# 1609           Меньше 100 тысяч     50000.00   70000.00
# 315            Больше 300 тысяч    150000.00  350000.00
# 1444  От 100 тысяч до 200 тысяч    120000.00  120000.00
# 1681  От 100 тысяч до 200 тысяч    108000.00  136000.00
# 193   От 200 тысяч до 300 тысяч          NaN  298000.00
# 1590           Больше 300 тысяч    150000.00  300000.00
# 17    От 100 тысяч до 200 тысяч    130000.00  180000.00
# 28    От 100 тысяч до 200 тысяч          NaN  140000.00
# 29    От 100 тысяч до 200 тысяч          NaN  140000.00

# %%
losses(data)
# Out:
# department: 76.26%
# salary_from: 81.05%
# salary_to: 86.36%
# key_skills_from_key_skills_field: 36.30%

# %%
data['salary_pair'] = data['salary_bin'].str.replace('От ', '', regex=True)\
                                        .str.replace('тысяч', '', regex=True)\
                                        .str.replace('до', ',', regex=True)

# Заменяем текстовые значения
data['salary_pair'] = data['salary_pair'].replace('ЗП не указана', np.NaN, regex=True)\
                                         .replace('Меньше', '-1 ,', regex=True)\
                                         .replace('Больше', '-1 ,', regex=True)

# Преобразуем только непустые значения в списки
data.loc[data['salary_pair'].notna(), 'salary_pair'] = data.loc[data['salary_pair'].notna(), 'salary_pair']\
    .apply(lambda x: x.split(','))

data[['salary_bin', 'salary_from', 'salary_to', 'salary_pair']].head(10)
# Out:
#                      salary_bin  salary_from  salary_to     salary_pair
# 338               ЗП не указана          NaN        NaN             NaN
# 1111              ЗП не указана          NaN        NaN             NaN
# 1579              ЗП не указана          NaN        NaN             NaN
# 571               ЗП не указана          NaN        NaN             NaN
# 12    От 100 тысяч до 200 тысяч    135000.00  185000.00  [100  ,  200 ]
# 246               ЗП не указана    150000.00        NaN             NaN
# 11                ЗП не указана    350000.00        NaN             NaN
# 23                ЗП не указана          NaN        NaN             NaN
# 1736              ЗП не указана          NaN        NaN             NaN
# 1737  От 100 тысяч до 200 тысяч    100000.00  120000.00  [100  ,  200 ]

# %%
# Обновляем salary_from и salary_to из salary_pair, если они отсутствуют
data['salary_from'] = data['salary_from'].fillna(
    data['salary_pair'].apply(lambda x: float(x[0]) * 1000 if isinstance(x, list) and x[0].strip().isdigit() else np.NaN)
)

data['salary_to'] = data['salary_to'].fillna(
    data['salary_pair'].apply(lambda x: float(x[1]) * 1000 if isinstance(x, list) and len(x) > 1 and x[1].strip().isdigit() else np.NaN)
)
data['salary_pair'] = data['salary_pair'].astype(str)

# %%
losses(data)
# Out:
# department: 76.26%
# salary_from: 78.42%
# salary_to: 86.36%
# key_skills_from_key_skills_field: 36.30%

# %% [markdown]
# ## Исследовательский анализ данных <a id='chapter5'></a>

# %% [markdown]
# ### Выявление грейда требуемых специалистов <a id='chapter6'></a>

# %%
data = data.loc[data['duplicates'] != 'возможный дубликат']

# %%
grade = data.pivot_table(index='dataset_type', columns='experience', values='id', aggfunc='count' )
grade
# Out:
# experience    Junior (no experince)  Junior+ (1-3 years)  Middle (3-6 years)  \
# dataset_type
# da                              120                  851                 430
# sa                               85                  828                 880
#
# experience    Senior (6+ years)
# dataset_type
# da                           10
# sa                           44

# %% [markdown]
# ### Определение доли грейдов<a id='chapter7'></a>

# %%
grade_ratio = grade.reset_index().set_index('dataset_type')
grade_ratio.columns = ['junior', 'junior+', 'middle', 'senior']
grade_ratio['total'] = grade_ratio['junior'] + grade_ratio['junior+'] + grade_ratio['middle'] + grade_ratio['senior']
grade_ratio['junior_ratio'] = grade_ratio['junior'] / grade_ratio['total'] * 100
grade_ratio['junior+_ratio'] = grade_ratio['junior+'] / grade_ratio['total'] * 100
grade_ratio['middle_ratio'] = grade_ratio['middle'] / grade_ratio['total'] * 100
grade_ratio['senior_ratio'] = grade_ratio['senior'] / grade_ratio['total'] * 100
grade_ratio = grade_ratio[['junior_ratio', 'junior+_ratio', 'middle_ratio', 'senior_ratio']]
grade_ratio
# Out:
#               junior_ratio  junior+_ratio  middle_ratio  senior_ratio
# dataset_type
# da                    8.50          60.31         30.47          0.71
# sa                    4.63          45.07         47.90          2.40

# %%
# Категории для визуализации
categories = grade_ratio.columns

# Создание подграфиков (sublots)
fig, axes = plt.subplots(1, len(grade_ratio), figsize=(15, 6), sharey=True)

# Построение графиков для каждого типа набора данных
for i, (dataset, row) in enumerate(grade_ratio.iterrows()):
    axes[i].bar(categories, row, color=['skyblue', 'orange', 'lightgreen', 'red'])
    axes[i].set_title(f'{dataset.upper()}', fontsize=14)
    axes[i].set_xlabel('Categories', fontsize=12)
    axes[i].set_xticks(range(len(categories)))
    axes[i].set_xticklabels(categories)
    if i == 0:  # Для первого графика добавить подпись оси Y
        axes[i].set_ylabel('Percentage (%)', fontsize=12)

# Общий заголовок
fig.suptitle('Percentage Distribution by Experience Level', fontsize=16)
plt.tight_layout(rect=[0, 0, 1, 0.95])

# Показ графиков
plt.show()

# %% [markdown]
# ### Определение типичного места работы<a id='chapter8'></a>

# %% [markdown]
# Определение типичного места работы для Аналитика Данных и Системного Аналитика по следующим параметрам: ТОП-работодателей, зарплата, тип занятости, график работы,
# Ответ нужен для грейдов Junior, Junior+, Middle, Senior

# %%
def top_employers(data, dataset_type):
 
    # фильтруем данные по dataset_type
    filtered_data = data[data['dataset_type'] == dataset_type]
    
    # уровни грейдов
    grades = ['Junior', 'Junior+', 'Middle', 'Senior']
    
    # создаём сабплоты
    fig, axes = plt.subplots(2, 2, figsize=(15, 10))
    axes = axes.flatten()
    
    for i, grade in enumerate(grades):
        # фильтрация данных по каждому грейду
        grade_data = filtered_data[filtered_data['experience'].str.contains(grade, na=False)]
        
        # группировка данных по работодателям и подсчёт количества публикаций
        top_employers = grade_data['employer'].value_counts().head()
        
        # построение барплота
        axes[i].barh(top_employers.index, top_employers.values, color='skyblue')
        axes[i].set_title(f' Топ-5 работадателей для {grade} ({dataset_type.upper()})', fontsize=12)
        axes[i].set_xlabel('Количество вакансий', fontsize=10)
        axes[i].set_ylabel('Работодатели', fontsize=10)
        axes[i].invert_yaxis()  # инвертируем ось y для лучшей читаемости
    
    # общий заголовок и настройка визуализации
    fig.suptitle(f'Топ-5 работодателей для {dataset_type.upper()}', fontsize=16)
    plt.tight_layout(rect=[0, 0, 1, 0.95])
    plt.show()

# %%
top_employers(data, dataset_type='da')

# %%
top_employers(data, dataset_type='sa')

# %%
def distribution(data, column, title_prefix):

    # уровни грейдов
    grades = ['Junior', 'Junior+', 'Middle', 'Senior']
    dataset_types = ['da', 'sa']
    colors = {'da': 'skyblue', 'sa': 'lightgreen'}
    
    # создаём сабплоты
    fig, axes = plt.subplots(2, 2, figsize=(15, 10))
    axes = axes.flatten()
    
    for i, grade in enumerate(grades):
        ax = axes[i]
        height = 0.4  # высота столбцов
        
        # словарь для хранения распределений по каждому типу специалистов
        distributions = {}
        
        # получаем данные для каждого типа специалистов
        for dataset_type in dataset_types:
            filtered_data = data[(data['dataset_type'] == dataset_type) &
                                 (data['experience'].str.contains(grade, na=False))]
            distribution = filtered_data[column].value_counts()
            distributions[dataset_type] = distribution
        
        # формируем общий список меток (категорий)
        categories = list(set(distributions['da'].index).union(set(distributions['sa'].index)))
        categories.sort()
        
        # индексы для категорий
        y = np.arange(len(categories))
        
        # построение столбцов для каждого типа специалистов
        for j, dataset_type in enumerate(dataset_types):
            values = [distributions[dataset_type].get(category, 0) for category in categories]
            ax.barh(y + j * height, values, height=height, label=f'{dataset_type.upper()}', color=colors[dataset_type])
        
        # настройка графика
        ax.set_title(f'{title_prefix} для {grade}', fontsize=12)
        ax.set_yticks(y + height / 2)
        ax.set_yticklabels(categories)
        ax.set_xlabel('Число вакансий', fontsize=10)
        ax.set_ylabel(column.replace('_', ' ').capitalize(), fontsize=10)
        ax.legend()

    # общий заголовок и настройка визуализации
    fig.suptitle(f'{title_prefix} представление для DA и SA', fontsize=16)
    plt.tight_layout(rect=[0, 0, 1, 0.95])
    plt.show()

# %%
distribution(data, column='salary_bin', title_prefix='Зарплатные ожидания,')

# %%
distribution(data, column='schedule', title_prefix='График работы,')

# %%
distribution(data, column='employment', title_prefix='Тип занятости,')

# %% [markdown]
# Определите, какие навыки спрашивают чаще hard или soft
# Определите наиболее желаемых кандидатов на вакансии Аналитика Данных и Системного Аналитика по следующим параметрам: самые важные hard-skills, cамые важные soft-skills. Ответ дайте отдельно для Junior, Junior+, Middle, Senior

# %%
def skill_distribution(data):
    """
    Визуализация распределения упоминаний hard и soft навыков в вакансиях,
    с разделением по грейдам (Junior, Junior+, Middle, Senior) и типам специалистов (da, sa).

    Args:
        data (pd.DataFrame): Исходный DataFrame с данными вакансий.

    Returns:
        None
    """
    # Уровни грейдов и типы специалистов
    grades = ['Junior', 'Junior+', 'Middle', 'Senior']
    dataset_types = ['da', 'sa']
    
    # Создаём подграфики
    fig, axes = plt.subplots(4, 2, figsize=(15, 20))
    axes = axes.flatten()

    for i, grade in enumerate(grades):
        for j, dataset_type in enumerate(dataset_types):
            # Фильтрация данных по грейду и типу
            filtered_data = data[(data['experience'].str.contains(grade, na=False)) &
                                 (data['dataset_type'] == dataset_type)].copy()  # Создание копии среза
            
            # Подсчёт навыков
            filtered_data.loc[:, 'hard_skill_count'] = filtered_data['hard_skills_from_description'].apply(
                lambda x: len(str(x).split(',')) if pd.notna(x) else 0)
            filtered_data.loc[:, 'soft_skill_count'] = filtered_data['soft_skills_from_description'].apply(
                lambda x: len(str(x).split(',')) if pd.notna(x) else 0)
            
            # Суммарное количество навыков
            total_hard_skills = filtered_data['hard_skill_count'].sum()
            total_soft_skills = filtered_data['soft_skill_count'].sum()
            
            # Данные для графика
            skill_types = ['Hard Skills', 'Soft Skills']
            counts = [total_hard_skills, total_soft_skills]
            
            # Построение графика
            ax = axes[i * 2 + j]
            ax.bar(skill_types, counts, color=['skyblue', 'lightgreen'])
            ax.set_title(f'{grade} ({dataset_type.upper()})', fontsize=12)
            ax.set_ylabel('Number of Mentions', fontsize=10)
            ax.set_xlabel('Skill Type', fontsize=10)
            
            # Добавление значений на столбцы
            for k, count in enumerate(counts):
                ax.text(k, count + 5, str(count), ha='center', fontsize=10)
    
    # Общий заголовок
    fig.suptitle('Skill Mentions by Grade and Type (DA and SA)', fontsize=16)
    plt.tight_layout(rect=[0, 0, 1, 0.95])
    plt.show()

# %%
skill_distribution(data)

# %%
def clean_skills(skill_list):
    """Функция для очистки и стандартизации списка навыков, исключая некорректные значения."""
    excluded_phrases = {"информация неизвестна", "не требуется"}  # Список исключаемых значений
    return [skill.strip().lower() for skill in skill_list if skill.strip() and skill.strip().lower() not in excluded_phrases]

def visualize_top_skills_by_grade_and_type(data, top_n=10):
    """
    Визуализация самых часто встречающихся hard skills и soft skills,
    с разделением по грейдам (Junior, Junior+, Middle, Senior) и типам специалистов (da, sa),
    отсортированная от большего к меньшему.

    Args:
        data (pd.DataFrame): Исходный DataFrame с данными вакансий.
        top_n (int): Количество навыков для отображения.

    Returns:
        None
    """
    # Уровни грейдов и типы специалистов
    grades = ['Junior', 'Junior+', 'Middle', 'Senior']
    dataset_types = ['da', 'sa']
    
    # Создаём подграфики
    fig, axes = plt.subplots(8, 2, figsize=(15, 40))  # 8 грейдов * 2 типа навыков (hard и soft)
    axes = axes.flatten()

    for i, grade in enumerate(grades):
        for j, dataset_type in enumerate(dataset_types):
            # Фильтрация данных по грейду и типу
            filtered_data = data[(data['experience'].str.contains(grade, na=False)) &
                                 (data['dataset_type'] == dataset_type)].copy()
            
            # Собираем hard skills и soft skills
            hard_skills = []
            soft_skills = []
            
            # Добавляем навыки в списки
            filtered_data['hard_skills_from_description'].dropna().apply(
                lambda x: hard_skills.extend(clean_skills(str(x).split(','))))
            filtered_data['soft_skills_from_description'].dropna().apply(
                lambda x: soft_skills.extend(clean_skills(str(x).split(','))))
            
            # Подсчитываем частоту навыков
            top_hard_skills = Counter(hard_skills).most_common(top_n)
            top_soft_skills = Counter(soft_skills).most_common(top_n)
            
            # Разделяем навыки и их количество для построения графиков
            hard_skill_labels, hard_skill_counts = zip(*top_hard_skills) if top_hard_skills else ([], [])
            soft_skill_labels, soft_skill_counts = zip(*top_soft_skills) if top_soft_skills else ([], [])
            
            # Инверсия порядка для сортировки от большего к меньшему
            hard_skill_labels = list(hard_skill_labels)[::-1]
            hard_skill_counts = list(hard_skill_counts)[::-1]
            soft_skill_labels = list(soft_skill_labels)[::-1]
            soft_skill_counts = list(soft_skill_counts)[::-1]
            
            # Индексы подграфиков
            hard_ax = axes[i * 4 + j * 2]  # Подграфик для hard skills
            soft_ax = axes[i * 4 + j * 2 + 1]  # Подграфик для soft skills
            
            # Построение графика для hard skills
            hard_ax.barh(hard_skill_labels, hard_skill_counts, color='skyblue')
            hard_ax.set_title(f'Top {top_n} Hard Skills ({grade}, {dataset_type.upper()})', fontsize=10)
            hard_ax.set_xlabel('Count', fontsize=8)
            hard_ax.set_ylabel('Skills', fontsize=8)
            
            # Построение графика для soft skills
            soft_ax.barh(soft_skill_labels, soft_skill_counts, color='lightgreen')
            soft_ax.set_title(f'Top {top_n} Soft Skills ({grade}, {dataset_type.upper()})', fontsize=10)
            soft_ax.set_xlabel('Count', fontsize=8)
            soft_ax.set_ylabel('Skills', fontsize=8)

    # Общий заголовок
    fig.suptitle('Top Hard and Soft Skills by Grade and Type (DA and SA)', fontsize=16)
    plt.tight_layout(rect=[0, 0, 1, 0.97])
    plt.show()

# %%
visualize_top_skills_by_grade_and_type(data, top_n=5)
